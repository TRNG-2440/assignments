# %% [markdown]
# # PySpark Built-in Functions Assignment
# ## Airline Booking Analytics — Revised Scope
#
# Excluded: arrays, maps, structs, window functions, and the complete pipeline.
#
# Run the setup cell and complete each TODO cell.

# %%
from pyspark.sql import functions as F
from pyspark.sql import SparkSession

# ----------------------------------------------------------------------------------------------------
# Class containing all spark logic
class SparkClass:
   
   # Parameterized Constructor
   def __init__(self, appName: str = "Airline Booking Analytics", master: str = "local[*]"):
      self.appName = appName
      self.master = master

   # Contains all Spark configurations
   def Configure(self) -> SparkSession:
      self.spark = (
         SparkSession.builder
         .appName(self.appName)
         .master(self.master)
         .getOrCreate()
      )

      return self.spark

columns = [
    "booking_id",
    "passenger_name",
    "airline_code",
    "route_code",
    "ticket_amount",
    "baggage_kg",
    "booking_date",
    "travel_date",
    "origin_city",
    "destination_city",
    "seat_class",
    "promo_discount",
    "services",
    "booking_status",
    "satisfaction_score",
    "payment_mode"
]

bookings = [(1001, '  aarav mehta  ', 'SKY', 'BLR-DEL', 8500.0, 15.0, '2026-01-05', '2026-02-10', 'Bengaluru', 'Delhi', 'Economy', None, 'Meal|WiFi', 'CONFIRMED', 4.5, 'Card'), (1002, 'DIYA IYER', 'NVA', 'DEL-BOM', 7200.0, 20.0, '2026-01-08', '2026-02-12', 'Delhi', 'Mumbai', 'Economy', 500.0, 'Meal|Priority Boarding', 'CONFIRMED', 4.2, 'UPI'), (1003, 'kabir khan', 'ORB', 'MAA-HYD', 6400.0, 10.0, '2026-01-10', '2026-02-15', 'Chennai', 'Hyderabad', 'Economy', 300.0, 'WiFi', 'COMPLETED', 3.8, 'Card'), (1004, 'Meera Das', 'ZEP', 'BOM-GOA', 5100.0, 7.0, '2026-01-12', '2026-02-18', 'Mumbai', 'Goa', 'Economy', None, 'Meal', 'CANCELLED', None, 'NetBanking'), (1005, '  nisha roy', 'LUM', 'CCU-DEL', 9300.0, 22.0, '2026-01-15', '2026-02-20', 'Kolkata', 'Delhi', 'Premium Economy', 750.0, 'Meal|WiFi|Lounge', 'CONFIRMED', 4.7, 'UPI'), (1006, 'ARJUN NAIR', 'SKY', 'BLR-MAA', 5800.0, 12.0, '2026-01-18', '2026-02-21', 'Bengaluru', 'Chennai', 'Economy', 250.0, 'Meal|WiFi', 'COMPLETED', 4.0, 'Card'), (1007, 'sana sheikh', 'NVA', 'HYD-BLR', 6900.0, 18.0, '2026-01-20', '2026-02-23', 'Hyderabad', 'Bengaluru', 'Economy', None, 'Priority Boarding', 'CONFIRMED', 4.1, 'Wallet'), (1008, 'Rohan  Sen', 'ORB', 'DEL-JAI', 4300.0, 5.0, '2026-01-22', '2026-02-25', 'Delhi', 'Jaipur', 'Economy', 200.0, None, 'COMPLETED', 3.6, 'UPI'), (1009, '  priya kapoor  ', 'ZEP', 'BLR-DEL', 12500.0, 25.0, '2026-01-25', '2026-03-01', 'Bengaluru', 'Delhi', 'Business', 1000.0, 'Meal|WiFi|Lounge|Priority Boarding', 'CONFIRMED', 4.9, 'Card'), (1010, 'VIKAS JAIN', 'LUM', 'DEL-BOM', 11800.0, 24.0, '2026-01-28', '2026-03-03', 'Delhi', 'Mumbai', 'Business', None, 'Meal|Lounge', 'CONFIRMED', 4.4, 'NetBanking'), (1011, 'ananya bose', 'SKY', 'MAA-HYD', 6100.0, 9.0, '2026-02-01', '2026-03-05', 'Chennai', 'Hyderabad', 'Economy', 350.0, 'Meal', 'COMPLETED', 4.0, 'UPI'), (1012, 'Karan Malhotra', 'NVA', 'BOM-GOA', 5400.0, 8.0, '2026-02-02', '2026-03-06', 'Mumbai', 'Goa', 'Economy', None, 'Meal|WiFi', 'CONFIRMED', 3.9, 'Card'), (1012, 'Karan Malhotra', 'NVA', 'BOM-GOA', 5400.0, 8.0, '2026-02-02', '2026-03-06', 'Mumbai', 'Goa', 'Economy', None, 'Meal|WiFi', 'CONFIRMED', 3.9, 'Card'), (1013, '  ishita paul', 'ORB', 'CCU-DEL', 8700.0, 16.0, '2026-02-04', '2026-03-08', 'Kolkata', 'Delhi', 'Premium Economy', 600.0, 'Meal|WiFi', 'COMPLETED', 4.3, 'Wallet'), (1014, 'MOHAN RAO', 'ZEP', 'BLR-MAA', 5900.0, 14.0, '2026-02-06', '2026-03-10', 'Bengaluru', 'Chennai', 'Economy', 300.0, 'Meal', 'CONFIRMED', 4.1, 'UPI'), (1015, 'leena joseph', 'LUM', 'HYD-BLR', 7600.0, 19.0, '2026-02-08', '2026-03-12', 'Hyderabad', 'Bengaluru', 'Premium Economy', None, 'WiFi|Priority Boarding', 'CANCELLED', 3.5, 'Card'), (1016, 'Dev Patel', 'SKY', 'DEL-JAI', 4500.0, 6.0, '2026-02-10', '2026-03-14', 'Delhi', 'Jaipur', 'Economy', 150.0, 'Meal', 'COMPLETED', 3.7, 'Cash'), (1017, '  kavya reddy  ', 'NVA', 'BLR-DEL', 8500.0, 15.0, '2026-02-12', '2026-03-16', 'Bengaluru', 'Delhi', 'Economy', 500.0, 'Meal|WiFi', 'CONFIRMED', 4.6, 'UPI'), (1018, 'RAHUL VERMA', 'ORB', 'DEL-BOM', 7200.0, 20.0, '2026-02-14', '2026-03-18', 'Delhi', 'Mumbai', 'Economy', None, 'Meal|Priority Boarding', 'CONFIRMED', 4.0, 'Card'), (1019, 'simran kaur', 'ZEP', 'MAA-HYD', 6400.0, 11.0, '2026-02-16', '2026-03-20', 'Chennai', 'Hyderabad', 'Economy', 250.0, 'WiFi', 'COMPLETED', 3.8, 'Wallet'), (1020, 'Naveen  Kumar', 'LUM', 'BOM-GOA', 5200.0, 7.5, '2026-02-18', '2026-03-22', 'Mumbai', 'Goa', 'Economy', None, 'Meal', 'CONFIRMED', 4.2, 'NetBanking'), (1021, '  tara singh', 'SKY', 'CCU-DEL', 9400.0, 21.0, '2026-02-20', '2026-03-24', 'Kolkata', 'Delhi', 'Premium Economy', 700.0, 'Meal|WiFi|Lounge', 'CONFIRMED', 4.8, 'Card'), (1022, 'AMAN GUPTA', 'NVA', 'BLR-MAA', 5800.0, 12.0, '2026-02-22', '2026-03-26', 'Bengaluru', 'Chennai', 'Economy', 200.0, 'Meal|WiFi', 'COMPLETED', 3.9, 'UPI'), (1023, 'pooja shah', 'ORB', 'HYD-BLR', 7000.0, 17.0, '2026-02-24', '2026-03-28', 'Hyderabad', 'Bengaluru', 'Economy', None, 'Priority Boarding', 'CONFIRMED', 4.1, 'Card'), (1024, 'Suresh Menon', 'ZEP', 'DEL-JAI', 4400.0, 5.5, '2026-02-26', '2026-03-30', 'Delhi', 'Jaipur', 'Economy', 180.0, None, 'COMPLETED', 3.6, 'Cash'), (1025, '  riya chatterjee  ', 'LUM', 'BLR-DEL', 12700.0, 26.0, '2026-03-01', '2026-04-02', 'Bengaluru', 'Delhi', 'Business', 1100.0, 'Meal|WiFi|Lounge|Priority Boarding', 'CONFIRMED', 4.9, 'Card'), (1026, 'ADITYA SINGH', 'SKY', 'DEL-BOM', 11900.0, 23.0, '2026-03-03', '2026-04-04', 'Delhi', 'Mumbai', 'Business', None, 'Meal|Lounge', 'CONFIRMED', 4.5, 'NetBanking'), (1027, 'neha pillai', 'NVA', 'MAA-HYD', 6200.0, 10.0, '2026-03-05', '2026-04-06', 'Chennai', 'Hyderabad', 'Economy', 300.0, 'Meal', 'COMPLETED', 4.0, 'UPI'), (1028, 'Harish  Babu', 'ORB', 'BOM-GOA', 5500.0, 8.0, '2026-03-07', '2026-04-08', 'Mumbai', 'Goa', 'Economy', None, 'Meal|WiFi', 'CONFIRMED', 3.8, 'Card'), (1029, '  zoya ali', 'ZEP', 'CCU-DEL', 8800.0, 16.0, '2026-03-09', '2026-04-10', 'Kolkata', 'Delhi', 'Premium Economy', 650.0, 'Meal|WiFi', 'COMPLETED', 4.4, 'Wallet'), (1030, 'MANOJ DAS', 'LUM', 'BLR-MAA', 6000.0, 13.0, '2026-03-11', '2026-04-12', 'Bengaluru', 'Chennai', 'Economy', 280.0, 'Meal', 'CONFIRMED', 4.0, 'UPI'), (1031, 'swati nair', 'SKY', 'HYD-BLR', 7700.0, 18.0, '2026-03-13', '2026-04-14', 'Hyderabad', 'Bengaluru', 'Premium Economy', None, 'WiFi|Priority Boarding', 'CANCELLED', 3.4, 'Card'), (1032, 'Ritesh Jain', 'NVA', 'DEL-JAI', 4600.0, 6.0, '2026-03-15', '2026-04-16', 'Delhi', 'Jaipur', 'Economy', 160.0, 'Meal', 'COMPLETED', 3.7, 'Cash'), (1033, '  lavanya krishnan ', 'ORB', 'BLR-DEL', 8600.0, 15.0, '2026-03-17', '2026-04-18', 'Bengaluru', 'Delhi', 'Economy', 450.0, 'Meal|WiFi', 'CONFIRMED', 4.5, 'UPI'), (1034, 'OM PRAKASH', 'ZEP', 'DEL-BOM', 7300.0, 20.0, '2026-03-19', '2026-04-20', 'Delhi', 'Mumbai', 'Economy', None, 'Meal|Priority Boarding', 'CONFIRMED', 4.1, 'Card'), (1035, 'farah khan', 'LUM', 'MAA-HYD', 6500.0, 11.0, '2026-03-21', '2026-04-22', 'Chennai', 'Hyderabad', 'Economy', 320.0, 'WiFi', 'COMPLETED', 3.9, 'Wallet'), (1036, '  gautam roy', 'UNK', 'BLR-DEL', 8100.0, 14.0, '2026-03-23', '2026-04-24', 'Bengaluru', 'Delhi', 'Economy', None, 'Meal', 'CONFIRMED', None, None)]

airline_columns = [
    "airline_code",
    "airline_name",
    "headquarters",
    "service_tier"
]
airlines = [('SKY', 'SkyBridge Airways', 'Bengaluru', 'Full Service'), ('NVA', 'NovaJet', 'Delhi', 'Low Cost'), ('ORB', 'Orbit Air', 'Mumbai', 'Low Cost'), ('ZEP', 'Zephyr Airlines', 'Hyderabad', 'Full Service'), ('LUM', 'Lumina Flights', 'Chennai', 'Hybrid'), ('PAC', 'Pacifica Air', 'Kochi', 'Regional')]

route_columns = [
    "route_code",
    "route_name",
    "region",
    "distance_km",
    "standard_duration_minutes"
]
routes = [('BLR-DEL', 'Bengaluru to Delhi', 'North-South', 1740, 165), ('DEL-BOM', 'Delhi to Mumbai', 'West', 1150, 130), ('MAA-HYD', 'Chennai to Hyderabad', 'South', 630, 75), ('BOM-GOA', 'Mumbai to Goa', 'West', 435, 65), ('CCU-DEL', 'Kolkata to Delhi', 'East-North', 1305, 145), ('BLR-MAA', 'Bengaluru to Chennai', 'South', 290, 60), ('HYD-BLR', 'Hyderabad to Bengaluru', 'South', 500, 70), ('DEL-JAI', 'Delhi to Jaipur', 'North', 240, 55)]

new_bookings = [(1037, '  tanvi desai', 'SKY', 'BOM-GOA', 5600.0, 9.0, '2026-03-25', '2026-04-26', 'Mumbai', 'Goa', 'Economy', 250.0, 'Meal|WiFi', 'CONFIRMED', 4.2, 'UPI'), (1038, 'YASH AGARWAL', 'NVA', 'CCU-DEL', 9000.0, 18.0, '2026-03-27', '2026-04-28', 'Kolkata', 'Delhi', 'Premium Economy', None, 'Meal|Lounge', 'CONFIRMED', 4.6, 'Card'), (1039, 'maria jose', 'ORB', 'BLR-MAA', 6050.0, 12.0, '2026-03-29', '2026-04-30', 'Bengaluru', 'Chennai', 'Economy', 200.0, 'Meal', 'COMPLETED', 4.0, 'Wallet'), (1040, '  vivek sharma  ', 'ZEP', 'HYD-BLR', 7800.0, 17.0, '2026-03-31', '2026-05-02', 'Hyderabad', 'Bengaluru', 'Premium Economy', 400.0, 'WiFi|Priority Boarding', 'CONFIRMED', 4.3, 'NetBanking')]

bookings_df = spark.createDataFrame(bookings, columns)
airline_df = spark.createDataFrame(airlines, airline_columns)
route_df = spark.createDataFrame(routes, route_columns)
new_bookings_df = spark.createDataFrame(new_bookings, columns)

print("Main dataset row count (includes one intentional duplicate):", bookings_df.count())
bookings_df.printSchema()
display(bookings_df)
# Out:
# Main dataset row count (includes one intentional duplicate): 37
# root
#  |-- booking_id: long (nullable = true)
#  |-- passenger_name: string (nullable = true)
#  |-- airline_code: string (nullable = true)
#  |-- route_code: string (nullable = true)
#  |-- ticket_amount: double (nullable = true)
#  |-- baggage_kg: double (nullable = true)
#  |-- booking_date: string (nullable = true)
#  |-- travel_date: string (nullable = true)
#  |-- origin_city: string (nullable = true)
#  |-- destination_city: string (nullable = true)
#  |-- seat_class: string (nullable = true)
#  |-- promo_discount: double (nullable = true)
#  |-- services: string (nullable = true)
#  |-- booking_status: string (nullable = true)
#  |-- satisfaction_score: double (nullable = true)
#  |-- payment_mode: string (nullable = true)
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>booking_id</th><th>passenger_name</th><th>airline_code</th><th>route_code</th><th>ticket_amount</th><th>baggage_kg</th><th>booking_date</th><th>travel_date</th><th>origin_city</th><th>destination_city</th><th>seat_class</th><th>promo_discount</th><th>services</th><th>booking_status</th><th>satisfaction_score</th><th>payment_mode</th></tr></thead><tbody><tr><td>1001</td><td>  aarav mehta  </td><td>SKY</td><td>BLR-DEL</td><td>8500.0</td><td>15.0</td><td>2026-01-05</td><td>2026-02-10</td><td>Bengaluru</td><td>Delhi</td><td>Economy</td><td>null</td><td>Meal|WiFi</td><td>CONFIRMED</td><td>4.5</td><td>Card</td></tr><tr><td>1002</td><td>DIYA IYER</td><td>NVA</td><td>DEL-BOM</td><td>7200.0</td><td>20.0</td><td>2026-01-08</td><td>2026-02-12</td><td>Delhi</td><td>Mumbai</td><td>Economy</td><td>500.0</td><td>Meal|Priority Boarding</td><td>CONFIRMED</td><td>4.2</td><td>UPI</td></tr><tr><td>1003</td><td>kabir khan</td><td>ORB</td><td>MAA-HYD</td><td>6400.0</td><td>10.0</td><td>2026-01-10</td><td>2026-02-15</td><td>Chennai</td><td>Hyderabad</td><td>Economy</td><td>300.0</td><td>WiFi</td><td>COMPLETED</td><td>3.8</td><td>Card</td></tr><tr><td>1004</td><td>Meera Das</td><td>ZEP</td><td>BOM-GOA</td><td>5100.0</td><td>7.0</td><td>2026-01-12</td><td>2026-02-18</td><td>Mumbai</td><td>Goa</td><td>Economy</td><td>null</td><td>Meal</td><td>CANCELLED</td><td>null</td><td>NetBanking</td></tr><tr><td>1005</td><td>  nisha roy</td><td>LUM</td><td>CCU-DEL</td><td>9300.0</td><td>22.0</td><td>2026-01-15</td><td>2026-02-20</td><td>Kolkata</td><td>Delhi</td><td>Premium Economy</td><td>750.0</td><td>Meal|WiFi|Lounge</td><td>CONFIRMED</td><td>4.7</td><td>UPI</td></tr><tr><td>1006</td><td>ARJUN NAIR</td><td>SKY</td><td>BLR-MAA</td><td>5800.0</td><td>12.0</td><td>2026-01-18</td><td>2026-02-21</td><td>Bengaluru</td><td>Chennai</td><td>Economy</td><td>250.0</td><td>Meal|WiFi</td><td>COMPLETED</td><td>4.0</td><td>Card</td></tr><tr><td>1007</td><td>sana sheikh</td><td>NVA</td><td>HYD-BLR</td><td>6900.0</td><td>18.0</td><td>2026-01-20</td><td>2026-02-23</td><td>Hyderabad</td><td>Bengaluru</td><td>Economy</td><td>null</td><td>Priority Boarding</td><td>CONFIRMED</td><td>4.1</td><td>Wallet</td></tr><tr><td>1008</td><td>Rohan  Sen</td><td>ORB</td><td>DEL-JAI</td><td>4300.0</td><td>5.0</td><td>2026-01-22</td><td>2026-02-25</td><td>Delhi</td><td>Jaipur</td><td>Economy</td><td>200.0</td><td>null</td><td>COMPLETED</td><td>3.6</td><td>UPI</td></tr><tr><td>1009</td><td>  priya kapoor  </td><td>ZEP</td><td>BLR-DEL</td><td>12500.0</td><td>25.0</td><td>2026-01-25</td><td>2026-03-01</td><td>Bengaluru</td><td>Delhi</td><td>Business</td><td>1000.0</td><td>Meal|WiFi|Lounge|Priority Boarding</td><td>CONFIRMED</td><td>4.9</td><td>Card</td></tr><tr><td>1010</td><td>VIKAS JAIN</td><td>LUM</td><td>DEL-BOM</td><td>11800.0</td><td>24.0</td><td>2026-01-28</td><td>2026-03-03</td><td>Delhi</td><td>Mumbai</td><td>Business</td><td>null</td><td>Meal|Lounge</td><td>CONFIRMED</td><td>4.4</td><td>NetBanking</td></tr><tr><td>1011</td><td>ananya bose</td><td>SKY</td><td>MAA-HYD</td><td>6100.0</td><td>9.0</td><td>2026-02-01</td><td>2026-03-05</td><td>Chennai</td><td>Hyderabad</td><td>Economy</td><td>350.0</td><td>Meal</td><td>COMPLETED</td><td>4.0</td><td>UPI</td></tr><tr><td>1012</td><td>Karan Malhotra</td><td>NVA</td><td>BOM-GOA</td><td>5400.0</td><td>8.0</td><td>2026-02-02</td><td>2026-03-06</td><td>Mumbai</td><td>Goa</td><td>Economy</td><td>null</td><td>Meal|WiFi</td><td>CONFIRMED</td><td>3.9</td><td>Card</td></tr><tr><td>1012</td><td>Karan Malhotra</td><td>NVA</td><td>BOM-GOA</td><td>5400.0</td><td>8.0</td><td>2026-02-02</td><td>2026-03-06</td><td>Mumbai</td><td>Goa</td><td>Economy</td><td>null</td><td>Meal|WiFi</td><td>CONFIRMED</td><td>3.9</td><td>Card</td></tr><tr><td>1013</td><td>  ishita paul</td><td>ORB</td><td>CCU-DEL</td><td>8700.0</td><td>16.0</td><td>2026-02-04</td><td>20 ...

# %% [markdown]
# ## Question 1 — DataFrame inspection
#
# Display the complete booking DataFrame without truncating long values. Print the schema and count the total records.
#
# **Functions/concepts:** `show, printSchema, count`

# %%
# TODO Question 1
# Write your PySpark solution below.

# Print dataframe schema
bookings_df.printSchema()

# Show All columns without being trimmed
bookings_df.show(truncate = False)

# Display amount of rows present in dataframe
print(bookings_df.count())
# Out:
# root
#  |-- booking_id: long (nullable = true)
#  |-- passenger_name: string (nullable = true)
#  |-- airline_code: string (nullable = true)
#  |-- route_code: string (nullable = true)
#  |-- ticket_amount: double (nullable = true)
#  |-- baggage_kg: double (nullable = true)
#  |-- booking_date: string (nullable = true)
#  |-- travel_date: string (nullable = true)
#  |-- origin_city: string (nullable = true)
#  |-- destination_city: string (nullable = true)
#  |-- seat_class: string (nullable = true)
#  |-- promo_discount: double (nullable = true)
#  |-- services: string (nullable = true)
#  |-- booking_status: string (nullable = true)
#  |-- satisfaction_score: double (nullable = true)
#  |-- payment_mode: string (nullable = true)
#
# +----------+----------------+------------+----------+-------------+----------+------------+-----------+-----------+----------------+---------------+--------------+----------------------------------+--------------+------------------+------------+
# |booking_id|passenger_name  |airline_code|route_code|ticket_amount|baggage_kg|booking_date|travel_date|origin_city|destination_city|seat_class     |promo_discount|services                          |booking_status|satisfaction_score|payment_mode|
# +----------+----------------+------------+----------+-------------+----------+------------+-----------+-----------+----------------+---------------+--------------+----------------------------------+--------------+------------------+------------+
# |1001      |  aarav mehta   |SKY         |BLR-DEL   |8500.0       |15.0      |2026-01-05  |2026-02-10 |Bengaluru  |Delhi           |Economy        |NULL          |Meal|WiFi                         |CONFIRMED     |4.5               |Card        |
# |1002      |DIYA IYER       |NVA         |DEL-BOM   |7200.0       |20.0      |2026-01-08  |2026-02-12 |Delhi      |Mumbai          |Economy        |500.0         |Meal|Priority Boarding            |CONFIRMED     |4.2               |UPI         |
# |1003      |kabir khan      |ORB         |MAA-HYD   |6400.0       |10.0      |2026-01-10  |2026-02-15 |Chennai    |Hyderabad       |Economy        |300.0         |WiFi                              |COMPLETED     |3.8               |Card        |
# |1004      |Meera Das       |ZEP         |BOM-GOA   |5100.0       |7.0       |2026-01-12  |2026-02-18 |Mumbai     |Goa             |Economy        |NULL          |Meal                              |CANCELLED     |NULL              |NetBanking  |
# |1005      |  nisha roy     |LUM         |CCU-DEL   |9300.0       |22.0      |2026-01-15  |2026-02-20 |Kolkata    |Delhi           |Premium Economy|750.0         |Meal|WiFi|Lounge                  |CONFIRMED     |4.7               |UPI         |
# |1006      |ARJUN NAIR      |SKY         |BLR-MAA   |5800.0       |12.0      |2026-01-18  |2026-02-21 |Bengaluru  |Chennai         |Economy        |250.0         |Meal|WiFi                         |COMPLETED     |4.0               |Card        |
# |1007      |sana sheikh     |NVA         |HYD-BLR   |6900.0       |18.0      |2026-01-20  |2026-02-23 |Hyderabad  |Bengaluru       |Economy        |NULL          |Priority Boarding                 |CONFIRMED     |4.1               |Wallet      |
# |1008      |Rohan  Sen      |ORB         |DEL-JAI   |4300.0       |5.0       |2026-01-22  |2026-02-25 |Delhi      |Jaipur          |Economy        |200.0         |NULL                              |COMPLETED     |3.6               |UPI         |
# |1009      |  priya kapoor  |ZEP         |BLR-DEL   |12500.0      |25.0      |2026-01-25  |2026-03-01 |Bengaluru  |Delhi           |Business       |1000.0        |Meal|WiFi|Lounge|Priority Boarding|CONFIRMED     |4.9               |Card        |
# |1010      |VIKAS JAIN      |LUM         |DEL-BOM   |11800.0      |24.0      |2026-01-28  |2026-03-03 |Delhi      |Mumbai          |Business       |NULL          |Meal|Lounge                       |CONFIRMED     |4.4               |NetBanking  |
# |1011      |ananya bose     |SKY         |MAA-HYD   |6100.0       |9.0       |2026-02-01  |2026-03-05 |Chennai    |Hyderabad       |Economy        |350.0         |Meal                              |COMPLETED     |4.0               |UPI         |
# |1012      |Karan Malhotra  |NVA         |BOM-GOA   |5400.0       |8.0       |2026-02-02  |2026-03-06 |Mumbai     |Goa             |Economy        |NULL          |Meal|WiFi                         |CONFIRMED     |3.9               |Card        |
# |1012      |Karan Malhotra  |NVA         |BOM-GOA   |5400.0       |8.0       |2026-02-02  |2026-03-06 |Mumbai     |Goa             |Economy        |NULL          |Meal|WiFi                         |CONFIRMED     |3.9               |Card        |
# |1013      |  ishita paul   |ORB         |CCU-DEL   |8700.0       |16.0      |2026-02-04  |2026-03-08 |Kolkata    |Delhi           |Premium Economy|600.0         |Meal|WiFi                         |COMPLETED     |4.3               |Wallet      |
# |1014      |MOHAN RAO       |ZEP         |BLR-MAA   |5900.0       |14.0      |2026-02-06  |2026-03-10 |Bengaluru  |Chennai         |Economy        |300.0         |Meal                              |CONFIRMED     |4.1               |UPI         |
# |1015      |leena joseph    |LUM         |HYD-BLR   |7600.0       |19.0      |2026-02-08  |2026-03-12 |Hyderabad  |Bengaluru       |Premium Economy|NULL          |WiFi|Priority Boarding            |CANCELLED     |3.5               |Card        |
# |1016      |Dev Patel       |SKY         |DEL-JAI   |4500.0       |6.0       |2026-02-10  |2026-03-14 |Delhi      |Jaipur          |Economy        |150.0         |Meal                              |COMPLETED     |3.7               |Cash        |
# |1017      |  kavya reddy   |NVA         |BLR-DEL   |8500.0       |15.0      |2026-02-12  |2026-03-16 |Bengaluru  |Delhi           |Economy        |500.0         |Meal|WiFi                         |CONFIRMED     |4.6               |UPI         |
# |1018      |RAHUL VERMA     |ORB         |DEL-BOM   |7200.0       |20.0      |2026-02-14  |2026-03-18 |Delhi      |Mumbai          |Economy        |NULL          |Meal|Priority Boarding            |CONFIRMED     |4.0               |Card        |
# |1019      |simran kaur     |ZEP         |MAA-HYD   |6400.0       |11.0      |2026-02-16  |2026-03-20 |Chennai    |Hyderabad       |Economy        |250.0         |WiFi                              |COMPLETED     |3.8               |Wallet      |
# +----------+----------------+------------+----------+-------------+----------+------------+-----------+-----------+----------------+---------------+--------------+----------------------------------+--------------+------------------+------------+
# only showing top 20 rows
# 37

# %% [markdown]
# ## Question 2 — Column operations
#
# Select only booking_id, passenger_name, airline_code, route_code, and ticket_amount.
#
# **Functions/concepts:** `select`

# %%
# TODO Question 2
# Write your PySpark solution below.


bookings_df.select(
    "booking_id",
    "passenger_name",
    "airline_code",
    "route_code",
    "ticket_amount"
).show(truncate=False)
# Out:
# +----------+----------------+------------+----------+-------------+
# |booking_id|passenger_name  |airline_code|route_code|ticket_amount|
# +----------+----------------+------------+----------+-------------+
# |1001      |  aarav mehta   |SKY         |BLR-DEL   |8500.0       |
# |1002      |DIYA IYER       |NVA         |DEL-BOM   |7200.0       |
# |1003      |kabir khan      |ORB         |MAA-HYD   |6400.0       |
# |1004      |Meera Das       |ZEP         |BOM-GOA   |5100.0       |
# |1005      |  nisha roy     |LUM         |CCU-DEL   |9300.0       |
# |1006      |ARJUN NAIR      |SKY         |BLR-MAA   |5800.0       |
# |1007      |sana sheikh     |NVA         |HYD-BLR   |6900.0       |
# |1008      |Rohan  Sen      |ORB         |DEL-JAI   |4300.0       |
# |1009      |  priya kapoor  |ZEP         |BLR-DEL   |12500.0      |
# |1010      |VIKAS JAIN      |LUM         |DEL-BOM   |11800.0      |
# |1011      |ananya bose     |SKY         |MAA-HYD   |6100.0       |
# |1012      |Karan Malhotra  |NVA         |BOM-GOA   |5400.0       |
# |1012      |Karan Malhotra  |NVA         |BOM-GOA   |5400.0       |
# |1013      |  ishita paul   |ORB         |CCU-DEL   |8700.0       |
# |1014      |MOHAN RAO       |ZEP         |BLR-MAA   |5900.0       |
# |1015      |leena joseph    |LUM         |HYD-BLR   |7600.0       |
# |1016      |Dev Patel       |SKY         |DEL-JAI   |4500.0       |
# |1017      |  kavya reddy   |NVA         |BLR-DEL   |8500.0       |
# |1018      |RAHUL VERMA     |ORB         |DEL-BOM   |7200.0       |
# |1019      |simran kaur     |ZEP         |MAA-HYD   |6400.0       |
# +----------+----------------+------------+----------+-------------+
# only showing top 20 rows

# %% [markdown]
# ## Question 3 — Column operations
#
# Use F.col() to select passenger_name and ticket_amount.
#
# **Functions/concepts:** `col`

# %%
# TODO Question 3
# Write your PySpark solution below.
bookings_df.select(
   F.col("passenger_name"),
   F.col("ticket_amount")
).show(truncate = False)
# Out:
# +----------------+-------------+
# |passenger_name  |ticket_amount|
# +----------------+-------------+
# |  aarav mehta   |8500.0       |
# |DIYA IYER       |7200.0       |
# |kabir khan      |6400.0       |
# |Meera Das       |5100.0       |
# |  nisha roy     |9300.0       |
# |ARJUN NAIR      |5800.0       |
# |sana sheikh     |6900.0       |
# |Rohan  Sen      |4300.0       |
# |  priya kapoor  |12500.0      |
# |VIKAS JAIN      |11800.0      |
# |ananya bose     |6100.0       |
# |Karan Malhotra  |5400.0       |
# |Karan Malhotra  |5400.0       |
# |  ishita paul   |8700.0       |
# |MOHAN RAO       |5900.0       |
# |leena joseph    |7600.0       |
# |Dev Patel       |4500.0       |
# |  kavya reddy   |8500.0       |
# |RAHUL VERMA     |7200.0       |
# |simran kaur     |6400.0       |
# +----------------+-------------+
# only showing top 20 rows

# %% [markdown]
# ## Question 4 — Column operations
#
# Rename passenger_name as traveller_name and ticket_amount as fare using alias().
#
# **Functions/concepts:** `alias`

# %%
bookings_df.select(
   F.col("passenger_name").alias("traveller_name"),
   F.col("ticket_amount").alias("fare")
).show(truncate = False)
# Out:
# +----------------+-------+
# |traveller_name  |fare   |
# +----------------+-------+
# |  aarav mehta   |8500.0 |
# |DIYA IYER       |7200.0 |
# |kabir khan      |6400.0 |
# |Meera Das       |5100.0 |
# |  nisha roy     |9300.0 |
# |ARJUN NAIR      |5800.0 |
# |sana sheikh     |6900.0 |
# |Rohan  Sen      |4300.0 |
# |  priya kapoor  |12500.0|
# |VIKAS JAIN      |11800.0|
# |ananya bose     |6100.0 |
# |Karan Malhotra  |5400.0 |
# |Karan Malhotra  |5400.0 |
# |  ishita paul   |8700.0 |
# |MOHAN RAO       |5900.0 |
# |leena joseph    |7600.0 |
# |Dev Patel       |4500.0 |
# |  kavya reddy   |8500.0 |
# |RAHUL VERMA     |7200.0 |
# |simran kaur     |6400.0 |
# +----------------+-------+
# only showing top 20 rows

# %% [markdown]
# ## Question 5 — Column operations
#
# Create a gross_amount column equal to ticket_amount + promo_discount. Treat a null discount as 0 before calculating.
#
# **Functions/concepts:** `withColumn, coalesce, lit`

# %%
# TODO Question 5
# Write your PySpark solution below.
bookings_df.withColumn(
    "gross_amount",
    F.col("ticket_amount") + F.coalesce(F.col("promo_discount"), F.lit(0))
).show(truncate=False)
# Out:
# +----------+----------------+------------+----------+-------------+----------+------------+-----------+-----------+----------------+---------------+--------------+----------------------------------+--------------+------------------+------------+------------+
# |booking_id|passenger_name  |airline_code|route_code|ticket_amount|baggage_kg|booking_date|travel_date|origin_city|destination_city|seat_class     |promo_discount|services                          |booking_status|satisfaction_score|payment_mode|gross_amount|
# +----------+----------------+------------+----------+-------------+----------+------------+-----------+-----------+----------------+---------------+--------------+----------------------------------+--------------+------------------+------------+------------+
# |1001      |  aarav mehta   |SKY         |BLR-DEL   |8500.0       |15.0      |2026-01-05  |2026-02-10 |Bengaluru  |Delhi           |Economy        |NULL          |Meal|WiFi                         |CONFIRMED     |4.5               |Card        |8500.0      |
# |1002      |DIYA IYER       |NVA         |DEL-BOM   |7200.0       |20.0      |2026-01-08  |2026-02-12 |Delhi      |Mumbai          |Economy        |500.0         |Meal|Priority Boarding            |CONFIRMED     |4.2               |UPI         |7700.0      |
# |1003      |kabir khan      |ORB         |MAA-HYD   |6400.0       |10.0      |2026-01-10  |2026-02-15 |Chennai    |Hyderabad       |Economy        |300.0         |WiFi                              |COMPLETED     |3.8               |Card        |6700.0      |
# |1004      |Meera Das       |ZEP         |BOM-GOA   |5100.0       |7.0       |2026-01-12  |2026-02-18 |Mumbai     |Goa             |Economy        |NULL          |Meal                              |CANCELLED     |NULL              |NetBanking  |5100.0      |
# |1005      |  nisha roy     |LUM         |CCU-DEL   |9300.0       |22.0      |2026-01-15  |2026-02-20 |Kolkata    |Delhi           |Premium Economy|750.0         |Meal|WiFi|Lounge                  |CONFIRMED     |4.7               |UPI         |10050.0     |
# |1006      |ARJUN NAIR      |SKY         |BLR-MAA   |5800.0       |12.0      |2026-01-18  |2026-02-21 |Bengaluru  |Chennai         |Economy        |250.0         |Meal|WiFi                         |COMPLETED     |4.0               |Card        |6050.0      |
# |1007      |sana sheikh     |NVA         |HYD-BLR   |6900.0       |18.0      |2026-01-20  |2026-02-23 |Hyderabad  |Bengaluru       |Economy        |NULL          |Priority Boarding                 |CONFIRMED     |4.1               |Wallet      |6900.0      |
# |1008      |Rohan  Sen      |ORB         |DEL-JAI   |4300.0       |5.0       |2026-01-22  |2026-02-25 |Delhi      |Jaipur          |Economy        |200.0         |NULL                              |COMPLETED     |3.6               |UPI         |4500.0      |
# |1009      |  priya kapoor  |ZEP         |BLR-DEL   |12500.0      |25.0      |2026-01-25  |2026-03-01 |Bengaluru  |Delhi           |Business       |1000.0        |Meal|WiFi|Lounge|Priority Boarding|CONFIRMED     |4.9               |Card        |13500.0     |
# |1010      |VIKAS JAIN      |LUM         |DEL-BOM   |11800.0      |24.0      |2026-01-28  |2026-03-03 |Delhi      |Mumbai          |Business       |NULL          |Meal|Lounge                       |CONFIRMED     |4.4               |NetBanking  |11800.0     |
# |1011      |ananya bose     |SKY         |MAA-HYD   |6100.0       |9.0       |2026-02-01  |2026-03-05 |Chennai    |Hyderabad       |Economy        |350.0         |Meal                              |COMPLETED     |4.0               |UPI         |6450.0      |
# |1012      |Karan Malhotra  |NVA         |BOM-GOA   |5400.0       |8.0       |2026-02-02  |2026-03-06 |Mumbai     |Goa             |Economy        |NULL          |Meal|WiFi                         |CONFIRMED     |3.9               |Card        |5400.0      |
# |1012      |Karan Malhotra  |NVA         |BOM-GOA   |5400.0       |8.0       |2026-02-02  |2026-03-06 |Mumbai     |Goa             |Economy        |NULL          |Meal|WiFi                         |CONFIRMED     |3.9               |Card        |5400.0      |
# |1013      |  ishita paul   |ORB         |CCU-DEL   |8700.0       |16.0      |2026-02-04  |2026-03-08 |Kolkata    |Delhi           |Premium Economy|600.0         |Meal|WiFi                         |COMPLETED     |4.3               |Wallet      |9300.0      |
# |1014      |MOHAN RAO       |ZEP         |BLR-MAA   |5900.0       |14.0      |2026-02-06  |2026-03-10 |Bengaluru  |Chennai         |Economy        |300.0         |Meal                              |CONFIRMED     |4.1               |UPI         |6200.0      |
# |1015      |leena joseph    |LUM         |HYD-BLR   |7600.0       |19.0      |2026-02-08  |2026-03-12 |Hyderabad  |Bengaluru       |Premium Economy|NULL          |WiFi|Priority Boarding            |CANCELLED     |3.5               |Card        |7600.0      |
# |1016      |Dev Patel       |SKY         |DEL-JAI   |4500.0       |6.0       |2026-02-10  |2026-03-14 |Delhi      |Jaipur          |Economy        |150.0         |Meal                              |COMPLETED     |3.7               |Cash        |4650.0      |
# |1017      |  kavya reddy   |NVA         |BLR-DEL   |8500.0       |15.0      |2026-02-12  |2026-03-16 |Bengaluru  |Delhi           |Economy        |500.0         |Meal|WiFi                         |CONFIRMED     |4.6               |UPI         |9000.0      |
# |1018      |RAHUL VERMA     |ORB         |DEL-BOM   |7200.0       |20.0      |2026-02-14  |2026-03-18 |Delhi      |Mumbai          |Economy        |NULL          |Meal|Priority Boarding            |CONFIRMED     |4.0               |Card        |7200.0      |
# |1019      |simran kaur     |ZEP         |MAA-HYD   |6400.0       |11.0      |2026-02-16  |2026-03-20 |Chennai    |Hyderabad       |Economy        |250.0         |WiFi                              |COMPLETED     |3.8               |Wallet      |6650.0      |
# +----------+----------------+------------+----------+-------------+----------+------------+-----------+-----------+----------------+---------------+--------------+----------------------------------+--------------+------------------+------------+------------+
# only showing top 20 rows

# %% [markdown]
# ## Question 6 — Column operations
#
# Rename booking_status to reservation_status using withColumnRenamed().
#
# **Functions/concepts:** `withColumnRenamed`

# %%
# TODO Question 6
# Write your PySpark solution below.
# Rename column from "book_status" to "reservation_status"
bookings_df.withColumnRenamed("book_status", "reservation_status").show(truncate = False)
# Out:
# +----------+----------------+------------+----------+-------------+----------+------------+-----------+-----------+----------------+---------------+--------------+----------------------------------+--------------+------------------+------------+
# |booking_id|passenger_name  |airline_code|route_code|ticket_amount|baggage_kg|booking_date|travel_date|origin_city|destination_city|seat_class     |promo_discount|services                          |booking_status|satisfaction_score|payment_mode|
# +----------+----------------+------------+----------+-------------+----------+------------+-----------+-----------+----------------+---------------+--------------+----------------------------------+--------------+------------------+------------+
# |1001      |  aarav mehta   |SKY         |BLR-DEL   |8500.0       |15.0      |2026-01-05  |2026-02-10 |Bengaluru  |Delhi           |Economy        |NULL          |Meal|WiFi                         |CONFIRMED     |4.5               |Card        |
# |1002      |DIYA IYER       |NVA         |DEL-BOM   |7200.0       |20.0      |2026-01-08  |2026-02-12 |Delhi      |Mumbai          |Economy        |500.0         |Meal|Priority Boarding            |CONFIRMED     |4.2               |UPI         |
# |1003      |kabir khan      |ORB         |MAA-HYD   |6400.0       |10.0      |2026-01-10  |2026-02-15 |Chennai    |Hyderabad       |Economy        |300.0         |WiFi                              |COMPLETED     |3.8               |Card        |
# |1004      |Meera Das       |ZEP         |BOM-GOA   |5100.0       |7.0       |2026-01-12  |2026-02-18 |Mumbai     |Goa             |Economy        |NULL          |Meal                              |CANCELLED     |NULL              |NetBanking  |
# |1005      |  nisha roy     |LUM         |CCU-DEL   |9300.0       |22.0      |2026-01-15  |2026-02-20 |Kolkata    |Delhi           |Premium Economy|750.0         |Meal|WiFi|Lounge                  |CONFIRMED     |4.7               |UPI         |
# |1006      |ARJUN NAIR      |SKY         |BLR-MAA   |5800.0       |12.0      |2026-01-18  |2026-02-21 |Bengaluru  |Chennai         |Economy        |250.0         |Meal|WiFi                         |COMPLETED     |4.0               |Card        |
# |1007      |sana sheikh     |NVA         |HYD-BLR   |6900.0       |18.0      |2026-01-20  |2026-02-23 |Hyderabad  |Bengaluru       |Economy        |NULL          |Priority Boarding                 |CONFIRMED     |4.1               |Wallet      |
# |1008      |Rohan  Sen      |ORB         |DEL-JAI   |4300.0       |5.0       |2026-01-22  |2026-02-25 |Delhi      |Jaipur          |Economy        |200.0         |NULL                              |COMPLETED     |3.6               |UPI         |
# |1009      |  priya kapoor  |ZEP         |BLR-DEL   |12500.0      |25.0      |2026-01-25  |2026-03-01 |Bengaluru  |Delhi           |Business       |1000.0        |Meal|WiFi|Lounge|Priority Boarding|CONFIRMED     |4.9               |Card        |
# |1010      |VIKAS JAIN      |LUM         |DEL-BOM   |11800.0      |24.0      |2026-01-28  |2026-03-03 |Delhi      |Mumbai          |Business       |NULL          |Meal|Lounge                       |CONFIRMED     |4.4               |NetBanking  |
# |1011      |ananya bose     |SKY         |MAA-HYD   |6100.0       |9.0       |2026-02-01  |2026-03-05 |Chennai    |Hyderabad       |Economy        |350.0         |Meal                              |COMPLETED     |4.0               |UPI         |
# |1012      |Karan Malhotra  |NVA         |BOM-GOA   |5400.0       |8.0       |2026-02-02  |2026-03-06 |Mumbai     |Goa             |Economy        |NULL          |Meal|WiFi                         |CONFIRMED     |3.9               |Card        |
# |1012      |Karan Malhotra  |NVA         |BOM-GOA   |5400.0       |8.0       |2026-02-02  |2026-03-06 |Mumbai     |Goa             |Economy        |NULL          |Meal|WiFi                         |CONFIRMED     |3.9               |Card        |
# |1013      |  ishita paul   |ORB         |CCU-DEL   |8700.0       |16.0      |2026-02-04  |2026-03-08 |Kolkata    |Delhi           |Premium Economy|600.0         |Meal|WiFi                         |COMPLETED     |4.3               |Wallet      |
# |1014      |MOHAN RAO       |ZEP         |BLR-MAA   |5900.0       |14.0      |2026-02-06  |2026-03-10 |Bengaluru  |Chennai         |Economy        |300.0         |Meal                              |CONFIRMED     |4.1               |UPI         |
# |1015      |leena joseph    |LUM         |HYD-BLR   |7600.0       |19.0      |2026-02-08  |2026-03-12 |Hyderabad  |Bengaluru       |Premium Economy|NULL          |WiFi|Priority Boarding            |CANCELLED     |3.5               |Card        |
# |1016      |Dev Patel       |SKY         |DEL-JAI   |4500.0       |6.0       |2026-02-10  |2026-03-14 |Delhi      |Jaipur          |Economy        |150.0         |Meal                              |COMPLETED     |3.7               |Cash        |
# |1017      |  kavya reddy   |NVA         |BLR-DEL   |8500.0       |15.0      |2026-02-12  |2026-03-16 |Bengaluru  |Delhi           |Economy        |500.0         |Meal|WiFi                         |CONFIRMED     |4.6               |UPI         |
# |1018      |RAHUL VERMA     |ORB         |DEL-BOM   |7200.0       |20.0      |2026-02-14  |2026-03-18 |Delhi      |Mumbai          |Economy        |NULL          |Meal|Priority Boarding            |CONFIRMED     |4.0               |Card        |
# |1019      |simran kaur     |ZEP         |MAA-HYD   |6400.0       |11.0      |2026-02-16  |2026-03-20 |Chennai    |Hyderabad       |Economy        |250.0         |WiFi                              |COMPLETED     |3.8               |Wallet      |
# +----------+----------------+------------+----------+-------------+----------+------------+-----------+-----------+----------------+---------------+--------------+----------------------------------+--------------+------------------+------------+
# only showing top 20 rows

# %% [markdown]
# ## Question 7 — Column operations
#
# Create a DataFrame without services and payment_mode.
#
# **Functions/concepts:** `drop`

# %%
# TODO Question 7
# Write your PySpark solution below.

# Drop services and payment_mode from dataframe
bookings_df.drop("services", "payment_mode").show(truncate = False)
# Out:
# +----------+----------------+------------+----------+-------------+----------+------------+-----------+-----------+----------------+---------------+--------------+--------------+------------------+
# |booking_id|passenger_name  |airline_code|route_code|ticket_amount|baggage_kg|booking_date|travel_date|origin_city|destination_city|seat_class     |promo_discount|booking_status|satisfaction_score|
# +----------+----------------+------------+----------+-------------+----------+------------+-----------+-----------+----------------+---------------+--------------+--------------+------------------+
# |1001      |  aarav mehta   |SKY         |BLR-DEL   |8500.0       |15.0      |2026-01-05  |2026-02-10 |Bengaluru  |Delhi           |Economy        |NULL          |CONFIRMED     |4.5               |
# |1002      |DIYA IYER       |NVA         |DEL-BOM   |7200.0       |20.0      |2026-01-08  |2026-02-12 |Delhi      |Mumbai          |Economy        |500.0         |CONFIRMED     |4.2               |
# |1003      |kabir khan      |ORB         |MAA-HYD   |6400.0       |10.0      |2026-01-10  |2026-02-15 |Chennai    |Hyderabad       |Economy        |300.0         |COMPLETED     |3.8               |
# |1004      |Meera Das       |ZEP         |BOM-GOA   |5100.0       |7.0       |2026-01-12  |2026-02-18 |Mumbai     |Goa             |Economy        |NULL          |CANCELLED     |NULL              |
# |1005      |  nisha roy     |LUM         |CCU-DEL   |9300.0       |22.0      |2026-01-15  |2026-02-20 |Kolkata    |Delhi           |Premium Economy|750.0         |CONFIRMED     |4.7               |
# |1006      |ARJUN NAIR      |SKY         |BLR-MAA   |5800.0       |12.0      |2026-01-18  |2026-02-21 |Bengaluru  |Chennai         |Economy        |250.0         |COMPLETED     |4.0               |
# |1007      |sana sheikh     |NVA         |HYD-BLR   |6900.0       |18.0      |2026-01-20  |2026-02-23 |Hyderabad  |Bengaluru       |Economy        |NULL          |CONFIRMED     |4.1               |
# |1008      |Rohan  Sen      |ORB         |DEL-JAI   |4300.0       |5.0       |2026-01-22  |2026-02-25 |Delhi      |Jaipur          |Economy        |200.0         |COMPLETED     |3.6               |
# |1009      |  priya kapoor  |ZEP         |BLR-DEL   |12500.0      |25.0      |2026-01-25  |2026-03-01 |Bengaluru  |Delhi           |Business       |1000.0        |CONFIRMED     |4.9               |
# |1010      |VIKAS JAIN      |LUM         |DEL-BOM   |11800.0      |24.0      |2026-01-28  |2026-03-03 |Delhi      |Mumbai          |Business       |NULL          |CONFIRMED     |4.4               |
# |1011      |ananya bose     |SKY         |MAA-HYD   |6100.0       |9.0       |2026-02-01  |2026-03-05 |Chennai    |Hyderabad       |Economy        |350.0         |COMPLETED     |4.0               |
# |1012      |Karan Malhotra  |NVA         |BOM-GOA   |5400.0       |8.0       |2026-02-02  |2026-03-06 |Mumbai     |Goa             |Economy        |NULL          |CONFIRMED     |3.9               |
# |1012      |Karan Malhotra  |NVA         |BOM-GOA   |5400.0       |8.0       |2026-02-02  |2026-03-06 |Mumbai     |Goa             |Economy        |NULL          |CONFIRMED     |3.9               |
# |1013      |  ishita paul   |ORB         |CCU-DEL   |8700.0       |16.0      |2026-02-04  |2026-03-08 |Kolkata    |Delhi           |Premium Economy|600.0         |COMPLETED     |4.3               |
# |1014      |MOHAN RAO       |ZEP         |BLR-MAA   |5900.0       |14.0      |2026-02-06  |2026-03-10 |Bengaluru  |Chennai         |Economy        |300.0         |CONFIRMED     |4.1               |
# |1015      |leena joseph    |LUM         |HYD-BLR   |7600.0       |19.0      |2026-02-08  |2026-03-12 |Hyderabad  |Bengaluru       |Premium Economy|NULL          |CANCELLED     |3.5               |
# |1016      |Dev Patel       |SKY         |DEL-JAI   |4500.0       |6.0       |2026-02-10  |2026-03-14 |Delhi      |Jaipur          |Economy        |150.0         |COMPLETED     |3.7               |
# |1017      |  kavya reddy   |NVA         |BLR-DEL   |8500.0       |15.0      |2026-02-12  |2026-03-16 |Bengaluru  |Delhi           |Economy        |500.0         |CONFIRMED     |4.6               |
# |1018      |RAHUL VERMA     |ORB         |DEL-BOM   |7200.0       |20.0      |2026-02-14  |2026-03-18 |Delhi      |Mumbai          |Economy        |NULL          |CONFIRMED     |4.0               |
# |1019      |simran kaur     |ZEP         |MAA-HYD   |6400.0       |11.0      |2026-02-16  |2026-03-20 |Chennai    |Hyderabad       |Economy        |250.0         |COMPLETED     |3.8               |
# +----------+----------------+------------+----------+-------------+----------+------------+-----------+-----------+----------------+---------------+--------------+--------------+------------------+
# only showing top 20 rows

# %% [markdown]
# ## Question 8 — Filtering
#
# Display bookings with ticket_amount greater than 8,000 using filter().
#
# **Functions/concepts:** `filter`

# %%
# TODO Question 8
# Write your PySpark solution below.

bookings_df.filter(F.col('ticket_amount') > 8000).show(truncate = False)
# Out:
# +----------+-------------------+------------+----------+-------------+----------+------------+-----------+-----------+----------------+---------------+--------------+----------------------------------+--------------+------------------+------------+
# |booking_id|passenger_name     |airline_code|route_code|ticket_amount|baggage_kg|booking_date|travel_date|origin_city|destination_city|seat_class     |promo_discount|services                          |booking_status|satisfaction_score|payment_mode|
# +----------+-------------------+------------+----------+-------------+----------+------------+-----------+-----------+----------------+---------------+--------------+----------------------------------+--------------+------------------+------------+
# |1001      |  aarav mehta      |SKY         |BLR-DEL   |8500.0       |15.0      |2026-01-05  |2026-02-10 |Bengaluru  |Delhi           |Economy        |NULL          |Meal|WiFi                         |CONFIRMED     |4.5               |Card        |
# |1005      |  nisha roy        |LUM         |CCU-DEL   |9300.0       |22.0      |2026-01-15  |2026-02-20 |Kolkata    |Delhi           |Premium Economy|750.0         |Meal|WiFi|Lounge                  |CONFIRMED     |4.7               |UPI         |
# |1009      |  priya kapoor     |ZEP         |BLR-DEL   |12500.0      |25.0      |2026-01-25  |2026-03-01 |Bengaluru  |Delhi           |Business       |1000.0        |Meal|WiFi|Lounge|Priority Boarding|CONFIRMED     |4.9               |Card        |
# |1010      |VIKAS JAIN         |LUM         |DEL-BOM   |11800.0      |24.0      |2026-01-28  |2026-03-03 |Delhi      |Mumbai          |Business       |NULL          |Meal|Lounge                       |CONFIRMED     |4.4               |NetBanking  |
# |1013      |  ishita paul      |ORB         |CCU-DEL   |8700.0       |16.0      |2026-02-04  |2026-03-08 |Kolkata    |Delhi           |Premium Economy|600.0         |Meal|WiFi                         |COMPLETED     |4.3               |Wallet      |
# |1017      |  kavya reddy      |NVA         |BLR-DEL   |8500.0       |15.0      |2026-02-12  |2026-03-16 |Bengaluru  |Delhi           |Economy        |500.0         |Meal|WiFi                         |CONFIRMED     |4.6               |UPI         |
# |1021      |  tara singh       |SKY         |CCU-DEL   |9400.0       |21.0      |2026-02-20  |2026-03-24 |Kolkata    |Delhi           |Premium Economy|700.0         |Meal|WiFi|Lounge                  |CONFIRMED     |4.8               |Card        |
# |1025      |  riya chatterjee  |LUM         |BLR-DEL   |12700.0      |26.0      |2026-03-01  |2026-04-02 |Bengaluru  |Delhi           |Business       |1100.0        |Meal|WiFi|Lounge|Priority Boarding|CONFIRMED     |4.9               |Card        |
# |1026      |ADITYA SINGH       |SKY         |DEL-BOM   |11900.0      |23.0      |2026-03-03  |2026-04-04 |Delhi      |Mumbai          |Business       |NULL          |Meal|Lounge                       |CONFIRMED     |4.5               |NetBanking  |
# |1029      |  zoya ali         |ZEP         |CCU-DEL   |8800.0       |16.0      |2026-03-09  |2026-04-10 |Kolkata    |Delhi           |Premium Economy|650.0         |Meal|WiFi                         |COMPLETED     |4.4               |Wallet      |
# |1033      |  lavanya krishnan |ORB         |BLR-DEL   |8600.0       |15.0      |2026-03-17  |2026-04-18 |Bengaluru  |Delhi           |Economy        |450.0         |Meal|WiFi                         |CONFIRMED     |4.5               |UPI         |
# |1036      |  gautam roy       |UNK         |BLR-DEL   |8100.0       |14.0      |2026-03-23  |2026-04-24 |Bengaluru  |Delhi           |Economy        |NULL          |Meal                              |CONFIRMED     |NULL              |NULL        |
# +----------+-------------------+------------+----------+-------------+----------+------------+-----------+-----------+----------------+---------------+--------------+----------------------------------+--------------+------------------+------------+

# %% [markdown]
# ## Question 9 — Filtering
#
# Repeat the previous condition using where().
#
# **Functions/concepts:** `where`

# %%
# TODO Question 9
# Write your PySpark solution below.
bookings_df.where(F.col('ticket_amount') > 8000).show(truncate = False)
# Out:
# +----------+-------------------+------------+----------+-------------+----------+------------+-----------+-----------+----------------+---------------+--------------+----------------------------------+--------------+------------------+------------+
# |booking_id|passenger_name     |airline_code|route_code|ticket_amount|baggage_kg|booking_date|travel_date|origin_city|destination_city|seat_class     |promo_discount|services                          |booking_status|satisfaction_score|payment_mode|
# +----------+-------------------+------------+----------+-------------+----------+------------+-----------+-----------+----------------+---------------+--------------+----------------------------------+--------------+------------------+------------+
# |1001      |  aarav mehta      |SKY         |BLR-DEL   |8500.0       |15.0      |2026-01-05  |2026-02-10 |Bengaluru  |Delhi           |Economy        |NULL          |Meal|WiFi                         |CONFIRMED     |4.5               |Card        |
# |1005      |  nisha roy        |LUM         |CCU-DEL   |9300.0       |22.0      |2026-01-15  |2026-02-20 |Kolkata    |Delhi           |Premium Economy|750.0         |Meal|WiFi|Lounge                  |CONFIRMED     |4.7               |UPI         |
# |1009      |  priya kapoor     |ZEP         |BLR-DEL   |12500.0      |25.0      |2026-01-25  |2026-03-01 |Bengaluru  |Delhi           |Business       |1000.0        |Meal|WiFi|Lounge|Priority Boarding|CONFIRMED     |4.9               |Card        |
# |1010      |VIKAS JAIN         |LUM         |DEL-BOM   |11800.0      |24.0      |2026-01-28  |2026-03-03 |Delhi      |Mumbai          |Business       |NULL          |Meal|Lounge                       |CONFIRMED     |4.4               |NetBanking  |
# |1013      |  ishita paul      |ORB         |CCU-DEL   |8700.0       |16.0      |2026-02-04  |2026-03-08 |Kolkata    |Delhi           |Premium Economy|600.0         |Meal|WiFi                         |COMPLETED     |4.3               |Wallet      |
# |1017      |  kavya reddy      |NVA         |BLR-DEL   |8500.0       |15.0      |2026-02-12  |2026-03-16 |Bengaluru  |Delhi           |Economy        |500.0         |Meal|WiFi                         |CONFIRMED     |4.6               |UPI         |
# |1021      |  tara singh       |SKY         |CCU-DEL   |9400.0       |21.0      |2026-02-20  |2026-03-24 |Kolkata    |Delhi           |Premium Economy|700.0         |Meal|WiFi|Lounge                  |CONFIRMED     |4.8               |Card        |
# |1025      |  riya chatterjee  |LUM         |BLR-DEL   |12700.0      |26.0      |2026-03-01  |2026-04-02 |Bengaluru  |Delhi           |Business       |1100.0        |Meal|WiFi|Lounge|Priority Boarding|CONFIRMED     |4.9               |Card        |
# |1026      |ADITYA SINGH       |SKY         |DEL-BOM   |11900.0      |23.0      |2026-03-03  |2026-04-04 |Delhi      |Mumbai          |Business       |NULL          |Meal|Lounge                       |CONFIRMED     |4.5               |NetBanking  |
# |1029      |  zoya ali         |ZEP         |CCU-DEL   |8800.0       |16.0      |2026-03-09  |2026-04-10 |Kolkata    |Delhi           |Premium Economy|650.0         |Meal|WiFi                         |COMPLETED     |4.4               |Wallet      |
# |1033      |  lavanya krishnan |ORB         |BLR-DEL   |8600.0       |15.0      |2026-03-17  |2026-04-18 |Bengaluru  |Delhi           |Economy        |450.0         |Meal|WiFi                         |CONFIRMED     |4.5               |UPI         |
# |1036      |  gautam roy       |UNK         |BLR-DEL   |8100.0       |14.0      |2026-03-23  |2026-04-24 |Bengaluru  |Delhi           |Economy        |NULL          |Meal                              |CONFIRMED     |NULL              |NULL        |
# +----------+-------------------+------------+----------+-------------+----------+------------+-----------+-----------+----------------+---------------+--------------+----------------------------------+--------------+------------------+------------+

# %% [markdown]
# ## Question 10 — Filtering
#
# Find confirmed Business or Premium Economy bookings whose ticket_amount is above 9,000.
#
# **Functions/concepts:** `filter, multiple conditions`

# %%
# TODO Question 10
# Write your PySpark solution below.
bookings_df.where(
    (F.col("booking_status") == "CONFIRMED")
    & (F.col("ticket_amount") > 9000)
    & F.col("seat_class").isin("Business", "Premium Economy")
).show(truncate=False)
# Out:
# +----------+-------------------+------------+----------+-------------+----------+------------+-----------+-----------+----------------+---------------+--------------+----------------------------------+--------------+------------------+------------+
# |booking_id|passenger_name     |airline_code|route_code|ticket_amount|baggage_kg|booking_date|travel_date|origin_city|destination_city|seat_class     |promo_discount|services                          |booking_status|satisfaction_score|payment_mode|
# +----------+-------------------+------------+----------+-------------+----------+------------+-----------+-----------+----------------+---------------+--------------+----------------------------------+--------------+------------------+------------+
# |1005      |  nisha roy        |LUM         |CCU-DEL   |9300.0       |22.0      |2026-01-15  |2026-02-20 |Kolkata    |Delhi           |Premium Economy|750.0         |Meal|WiFi|Lounge                  |CONFIRMED     |4.7               |UPI         |
# |1009      |  priya kapoor     |ZEP         |BLR-DEL   |12500.0      |25.0      |2026-01-25  |2026-03-01 |Bengaluru  |Delhi           |Business       |1000.0        |Meal|WiFi|Lounge|Priority Boarding|CONFIRMED     |4.9               |Card        |
# |1010      |VIKAS JAIN         |LUM         |DEL-BOM   |11800.0      |24.0      |2026-01-28  |2026-03-03 |Delhi      |Mumbai          |Business       |NULL          |Meal|Lounge                       |CONFIRMED     |4.4               |NetBanking  |
# |1021      |  tara singh       |SKY         |CCU-DEL   |9400.0       |21.0      |2026-02-20  |2026-03-24 |Kolkata    |Delhi           |Premium Economy|700.0         |Meal|WiFi|Lounge                  |CONFIRMED     |4.8               |Card        |
# |1025      |  riya chatterjee  |LUM         |BLR-DEL   |12700.0      |26.0      |2026-03-01  |2026-04-02 |Bengaluru  |Delhi           |Business       |1100.0        |Meal|WiFi|Lounge|Priority Boarding|CONFIRMED     |4.9               |Card        |
# |1026      |ADITYA SINGH       |SKY         |DEL-BOM   |11900.0      |23.0      |2026-03-03  |2026-04-04 |Delhi      |Mumbai          |Business       |NULL          |Meal|Lounge                       |CONFIRMED     |4.5               |NetBanking  |
# +----------+-------------------+------------+----------+-------------+----------+------------+-----------+-----------+----------------+---------------+--------------+----------------------------------+--------------+------------------+------------+

# %% [markdown]
# ## Question 11 — Filtering
#
# Find bookings belonging to SKY, NVA, or ORB using isin().
#
# **Functions/concepts:** `isin`

# %%
# TODO Question 11
# Write your PySpark solution below.
bookings_df.filter(
   
   F.col("airline_code").isin("SKY","NVA","ORB")
).show(truncate = False)
# Out:
# +----------+---------------+------------+----------+-------------+----------+------------+-----------+-----------+----------------+---------------+--------------+----------------------+--------------+------------------+------------+
# |booking_id|passenger_name |airline_code|route_code|ticket_amount|baggage_kg|booking_date|travel_date|origin_city|destination_city|seat_class     |promo_discount|services              |booking_status|satisfaction_score|payment_mode|
# +----------+---------------+------------+----------+-------------+----------+------------+-----------+-----------+----------------+---------------+--------------+----------------------+--------------+------------------+------------+
# |1001      |  aarav mehta  |SKY         |BLR-DEL   |8500.0       |15.0      |2026-01-05  |2026-02-10 |Bengaluru  |Delhi           |Economy        |NULL          |Meal|WiFi             |CONFIRMED     |4.5               |Card        |
# |1002      |DIYA IYER      |NVA         |DEL-BOM   |7200.0       |20.0      |2026-01-08  |2026-02-12 |Delhi      |Mumbai          |Economy        |500.0         |Meal|Priority Boarding|CONFIRMED     |4.2               |UPI         |
# |1003      |kabir khan     |ORB         |MAA-HYD   |6400.0       |10.0      |2026-01-10  |2026-02-15 |Chennai    |Hyderabad       |Economy        |300.0         |WiFi                  |COMPLETED     |3.8               |Card        |
# |1006      |ARJUN NAIR     |SKY         |BLR-MAA   |5800.0       |12.0      |2026-01-18  |2026-02-21 |Bengaluru  |Chennai         |Economy        |250.0         |Meal|WiFi             |COMPLETED     |4.0               |Card        |
# |1007      |sana sheikh    |NVA         |HYD-BLR   |6900.0       |18.0      |2026-01-20  |2026-02-23 |Hyderabad  |Bengaluru       |Economy        |NULL          |Priority Boarding     |CONFIRMED     |4.1               |Wallet      |
# |1008      |Rohan  Sen     |ORB         |DEL-JAI   |4300.0       |5.0       |2026-01-22  |2026-02-25 |Delhi      |Jaipur          |Economy        |200.0         |NULL                  |COMPLETED     |3.6               |UPI         |
# |1011      |ananya bose    |SKY         |MAA-HYD   |6100.0       |9.0       |2026-02-01  |2026-03-05 |Chennai    |Hyderabad       |Economy        |350.0         |Meal                  |COMPLETED     |4.0               |UPI         |
# |1012      |Karan Malhotra |NVA         |BOM-GOA   |5400.0       |8.0       |2026-02-02  |2026-03-06 |Mumbai     |Goa             |Economy        |NULL          |Meal|WiFi             |CONFIRMED     |3.9               |Card        |
# |1012      |Karan Malhotra |NVA         |BOM-GOA   |5400.0       |8.0       |2026-02-02  |2026-03-06 |Mumbai     |Goa             |Economy        |NULL          |Meal|WiFi             |CONFIRMED     |3.9               |Card        |
# |1013      |  ishita paul  |ORB         |CCU-DEL   |8700.0       |16.0      |2026-02-04  |2026-03-08 |Kolkata    |Delhi           |Premium Economy|600.0         |Meal|WiFi             |COMPLETED     |4.3               |Wallet      |
# |1016      |Dev Patel      |SKY         |DEL-JAI   |4500.0       |6.0       |2026-02-10  |2026-03-14 |Delhi      |Jaipur          |Economy        |150.0         |Meal                  |COMPLETED     |3.7               |Cash        |
# |1017      |  kavya reddy  |NVA         |BLR-DEL   |8500.0       |15.0      |2026-02-12  |2026-03-16 |Bengaluru  |Delhi           |Economy        |500.0         |Meal|WiFi             |CONFIRMED     |4.6               |UPI         |
# |1018      |RAHUL VERMA    |ORB         |DEL-BOM   |7200.0       |20.0      |2026-02-14  |2026-03-18 |Delhi      |Mumbai          |Economy        |NULL          |Meal|Priority Boarding|CONFIRMED     |4.0               |Card        |
# |1021      |  tara singh   |SKY         |CCU-DEL   |9400.0       |21.0      |2026-02-20  |2026-03-24 |Kolkata    |Delhi           |Premium Economy|700.0         |Meal|WiFi|Lounge      |CONFIRMED     |4.8               |Card        |
# |1022      |AMAN GUPTA     |NVA         |BLR-MAA   |5800.0       |12.0      |2026-02-22  |2026-03-26 |Bengaluru  |Chennai         |Economy        |200.0         |Meal|WiFi             |COMPLETED     |3.9               |UPI         |
# |1023      |pooja shah     |ORB         |HYD-BLR   |7000.0       |17.0      |2026-02-24  |2026-03-28 |Hyderabad  |Bengaluru       |Economy        |NULL          |Priority Boarding     |CONFIRMED     |4.1               |Card        |
# |1026      |ADITYA SINGH   |SKY         |DEL-BOM   |11900.0      |23.0      |2026-03-03  |2026-04-04 |Delhi      |Mumbai          |Business       |NULL          |Meal|Lounge           |CONFIRMED     |4.5               |NetBanking  |
# |1027      |neha pillai    |NVA         |MAA-HYD   |6200.0       |10.0      |2026-03-05  |2026-04-06 |Chennai    |Hyderabad       |Economy        |300.0         |Meal                  |COMPLETED     |4.0               |UPI         |
# |1028      |Harish  Babu   |ORB         |BOM-GOA   |5500.0       |8.0       |2026-03-07  |2026-04-08 |Mumbai     |Goa             |Economy        |NULL          |Meal|WiFi             |CONFIRMED     |3.8               |Card        |
# |1031      |swati nair     |SKY         |HYD-BLR   |7700.0       |18.0      |2026-03-13  |2026-04-14 |Hyderabad  |Bengaluru       |Premium Economy|NULL          |WiFi|Priority Boarding|CANCELLED     |3.4               |Card        |
# +----------+---------------+------------+----------+-------------+----------+------------+-----------+-----------+----------------+---------------+--------------+----------------------+--------------+------------------+------------+
# only showing top 20 rows

# %% [markdown]
# ## Question 12 — Filtering
#
# Find bookings with baggage_kg between 10 and 18 kilograms, inclusive.
#
# **Functions/concepts:** `between`

# %%
# TODO Question 12
# Write your PySpark solution below.
bookings_df.filter(
   F.col("baggage_kg").between(10,18)
).show(truncate = False)
# Out:
# +----------+-------------------+------------+----------+-------------+----------+------------+-----------+-----------+----------------+---------------+--------------+----------------------+--------------+------------------+------------+
# |booking_id|passenger_name     |airline_code|route_code|ticket_amount|baggage_kg|booking_date|travel_date|origin_city|destination_city|seat_class     |promo_discount|services              |booking_status|satisfaction_score|payment_mode|
# +----------+-------------------+------------+----------+-------------+----------+------------+-----------+-----------+----------------+---------------+--------------+----------------------+--------------+------------------+------------+
# |1001      |  aarav mehta      |SKY         |BLR-DEL   |8500.0       |15.0      |2026-01-05  |2026-02-10 |Bengaluru  |Delhi           |Economy        |NULL          |Meal|WiFi             |CONFIRMED     |4.5               |Card        |
# |1003      |kabir khan         |ORB         |MAA-HYD   |6400.0       |10.0      |2026-01-10  |2026-02-15 |Chennai    |Hyderabad       |Economy        |300.0         |WiFi                  |COMPLETED     |3.8               |Card        |
# |1006      |ARJUN NAIR         |SKY         |BLR-MAA   |5800.0       |12.0      |2026-01-18  |2026-02-21 |Bengaluru  |Chennai         |Economy        |250.0         |Meal|WiFi             |COMPLETED     |4.0               |Card        |
# |1007      |sana sheikh        |NVA         |HYD-BLR   |6900.0       |18.0      |2026-01-20  |2026-02-23 |Hyderabad  |Bengaluru       |Economy        |NULL          |Priority Boarding     |CONFIRMED     |4.1               |Wallet      |
# |1013      |  ishita paul      |ORB         |CCU-DEL   |8700.0       |16.0      |2026-02-04  |2026-03-08 |Kolkata    |Delhi           |Premium Economy|600.0         |Meal|WiFi             |COMPLETED     |4.3               |Wallet      |
# |1014      |MOHAN RAO          |ZEP         |BLR-MAA   |5900.0       |14.0      |2026-02-06  |2026-03-10 |Bengaluru  |Chennai         |Economy        |300.0         |Meal                  |CONFIRMED     |4.1               |UPI         |
# |1017      |  kavya reddy      |NVA         |BLR-DEL   |8500.0       |15.0      |2026-02-12  |2026-03-16 |Bengaluru  |Delhi           |Economy        |500.0         |Meal|WiFi             |CONFIRMED     |4.6               |UPI         |
# |1019      |simran kaur        |ZEP         |MAA-HYD   |6400.0       |11.0      |2026-02-16  |2026-03-20 |Chennai    |Hyderabad       |Economy        |250.0         |WiFi                  |COMPLETED     |3.8               |Wallet      |
# |1022      |AMAN GUPTA         |NVA         |BLR-MAA   |5800.0       |12.0      |2026-02-22  |2026-03-26 |Bengaluru  |Chennai         |Economy        |200.0         |Meal|WiFi             |COMPLETED     |3.9               |UPI         |
# |1023      |pooja shah         |ORB         |HYD-BLR   |7000.0       |17.0      |2026-02-24  |2026-03-28 |Hyderabad  |Bengaluru       |Economy        |NULL          |Priority Boarding     |CONFIRMED     |4.1               |Card        |
# |1027      |neha pillai        |NVA         |MAA-HYD   |6200.0       |10.0      |2026-03-05  |2026-04-06 |Chennai    |Hyderabad       |Economy        |300.0         |Meal                  |COMPLETED     |4.0               |UPI         |
# |1029      |  zoya ali         |ZEP         |CCU-DEL   |8800.0       |16.0      |2026-03-09  |2026-04-10 |Kolkata    |Delhi           |Premium Economy|650.0         |Meal|WiFi             |COMPLETED     |4.4               |Wallet      |
# |1030      |MANOJ DAS          |LUM         |BLR-MAA   |6000.0       |13.0      |2026-03-11  |2026-04-12 |Bengaluru  |Chennai         |Economy        |280.0         |Meal                  |CONFIRMED     |4.0               |UPI         |
# |1031      |swati nair         |SKY         |HYD-BLR   |7700.0       |18.0      |2026-03-13  |2026-04-14 |Hyderabad  |Bengaluru       |Premium Economy|NULL          |WiFi|Priority Boarding|CANCELLED     |3.4               |Card        |
# |1033      |  lavanya krishnan |ORB         |BLR-DEL   |8600.0       |15.0      |2026-03-17  |2026-04-18 |Bengaluru  |Delhi           |Economy        |450.0         |Meal|WiFi             |CONFIRMED     |4.5               |UPI         |
# |1035      |farah khan         |LUM         |MAA-HYD   |6500.0       |11.0      |2026-03-21  |2026-04-22 |Chennai    |Hyderabad       |Economy        |320.0         |WiFi                  |COMPLETED     |3.9               |Wallet      |
# |1036      |  gautam roy       |UNK         |BLR-DEL   |8100.0       |14.0      |2026-03-23  |2026-04-24 |Bengaluru  |Delhi           |Economy        |NULL          |Meal                  |CONFIRMED     |NULL              |NULL        |
# +----------+-------------------+------------+----------+-------------+----------+------------+-----------+-----------+----------------+---------------+--------------+----------------------+--------------+------------------+------------+

# %% [markdown]
# ## Question 13 — Duplicates
#
# Display the unique seat_class values.
#
# **Functions/concepts:** `distinct`

# %%
# TODO Question 13
# Write your PySpark solution below.

bookings_df.select("seat_class").distinct().show(truncate=False)
# Out:
# +---------------+
# |seat_class     |
# +---------------+
# |Economy        |
# |Premium Economy|
# |Business       |
# +---------------+

# %% [markdown]
# ## Question 14 — Duplicates
#
# Remove duplicate records based on booking_id and confirm the new row count.
#
# **Functions/concepts:** `dropDuplicates, count`

# %%
# TODO Question 14
# Write your PySpark solution below.

filtered_df = bookings_df.dropDuplicates(["booking_id"])

print(f'\nCount: {filtered_df.count()}')

filtered_df.show(truncate = False)
# Out:
# Count: 36
# +----------+----------------+------------+----------+-------------+----------+------------+-----------+-----------+----------------+---------------+--------------+----------------------------------+--------------+------------------+------------+
# |booking_id|passenger_name  |airline_code|route_code|ticket_amount|baggage_kg|booking_date|travel_date|origin_city|destination_city|seat_class     |promo_discount|services                          |booking_status|satisfaction_score|payment_mode|
# +----------+----------------+------------+----------+-------------+----------+------------+-----------+-----------+----------------+---------------+--------------+----------------------------------+--------------+------------------+------------+
# |1001      |  aarav mehta   |SKY         |BLR-DEL   |8500.0       |15.0      |2026-01-05  |2026-02-10 |Bengaluru  |Delhi           |Economy        |NULL          |Meal|WiFi                         |CONFIRMED     |4.5               |Card        |
# |1002      |DIYA IYER       |NVA         |DEL-BOM   |7200.0       |20.0      |2026-01-08  |2026-02-12 |Delhi      |Mumbai          |Economy        |500.0         |Meal|Priority Boarding            |CONFIRMED     |4.2               |UPI         |
# |1003      |kabir khan      |ORB         |MAA-HYD   |6400.0       |10.0      |2026-01-10  |2026-02-15 |Chennai    |Hyderabad       |Economy        |300.0         |WiFi                              |COMPLETED     |3.8               |Card        |
# |1004      |Meera Das       |ZEP         |BOM-GOA   |5100.0       |7.0       |2026-01-12  |2026-02-18 |Mumbai     |Goa             |Economy        |NULL          |Meal                              |CANCELLED     |NULL              |NetBanking  |
# |1005      |  nisha roy     |LUM         |CCU-DEL   |9300.0       |22.0      |2026-01-15  |2026-02-20 |Kolkata    |Delhi           |Premium Economy|750.0         |Meal|WiFi|Lounge                  |CONFIRMED     |4.7               |UPI         |
# |1006      |ARJUN NAIR      |SKY         |BLR-MAA   |5800.0       |12.0      |2026-01-18  |2026-02-21 |Bengaluru  |Chennai         |Economy        |250.0         |Meal|WiFi                         |COMPLETED     |4.0               |Card        |
# |1007      |sana sheikh     |NVA         |HYD-BLR   |6900.0       |18.0      |2026-01-20  |2026-02-23 |Hyderabad  |Bengaluru       |Economy        |NULL          |Priority Boarding                 |CONFIRMED     |4.1               |Wallet      |
# |1008      |Rohan  Sen      |ORB         |DEL-JAI   |4300.0       |5.0       |2026-01-22  |2026-02-25 |Delhi      |Jaipur          |Economy        |200.0         |NULL                              |COMPLETED     |3.6               |UPI         |
# |1009      |  priya kapoor  |ZEP         |BLR-DEL   |12500.0      |25.0      |2026-01-25  |2026-03-01 |Bengaluru  |Delhi           |Business       |1000.0        |Meal|WiFi|Lounge|Priority Boarding|CONFIRMED     |4.9               |Card        |
# |1010      |VIKAS JAIN      |LUM         |DEL-BOM   |11800.0      |24.0      |2026-01-28  |2026-03-03 |Delhi      |Mumbai          |Business       |NULL          |Meal|Lounge                       |CONFIRMED     |4.4               |NetBanking  |
# |1011      |ananya bose     |SKY         |MAA-HYD   |6100.0       |9.0       |2026-02-01  |2026-03-05 |Chennai    |Hyderabad       |Economy        |350.0         |Meal                              |COMPLETED     |4.0               |UPI         |
# |1012      |Karan Malhotra  |NVA         |BOM-GOA   |5400.0       |8.0       |2026-02-02  |2026-03-06 |Mumbai     |Goa             |Economy        |NULL          |Meal|WiFi                         |CONFIRMED     |3.9               |Card        |
# |1013      |  ishita paul   |ORB         |CCU-DEL   |8700.0       |16.0      |2026-02-04  |2026-03-08 |Kolkata    |Delhi           |Premium Economy|600.0         |Meal|WiFi                         |COMPLETED     |4.3               |Wallet      |
# |1014      |MOHAN RAO       |ZEP         |BLR-MAA   |5900.0       |14.0      |2026-02-06  |2026-03-10 |Bengaluru  |Chennai         |Economy        |300.0         |Meal                              |CONFIRMED     |4.1               |UPI         |
# |1015      |leena joseph    |LUM         |HYD-BLR   |7600.0       |19.0      |2026-02-08  |2026-03-12 |Hyderabad  |Bengaluru       |Premium Economy|NULL          |WiFi|Priority Boarding            |CANCELLED     |3.5               |Card        |
# |1016      |Dev Patel       |SKY         |DEL-JAI   |4500.0       |6.0       |2026-02-10  |2026-03-14 |Delhi      |Jaipur          |Economy        |150.0         |Meal                              |COMPLETED     |3.7               |Cash        |
# |1017      |  kavya reddy   |NVA         |BLR-DEL   |8500.0       |15.0      |2026-02-12  |2026-03-16 |Bengaluru  |Delhi           |Economy        |500.0         |Meal|WiFi                         |CONFIRMED     |4.6               |UPI         |
# |1018      |RAHUL VERMA     |ORB         |DEL-BOM   |7200.0       |20.0      |2026-02-14  |2026-03-18 |Delhi      |Mumbai          |Economy        |NULL          |Meal|Priority Boarding            |CONFIRMED     |4.0               |Card        |
# |1019      |simran kaur     |ZEP         |MAA-HYD   |6400.0       |11.0      |2026-02-16  |2026-03-20 |Chennai    |Hyderabad       |Economy        |250.0         |WiFi                              |COMPLETED     |3.8               |Wallet      |
# |1020      |Naveen  Kumar   |LUM         |BOM-GOA   |5200.0       |7.5       |2026-02-18  |2026-03-22 |Mumbai     |Goa             |Economy        |NULL          |Meal                              |CONFIRMED     |4.2               |NetBanking  |
# +----------+----------------+------------+----------+-------------+----------+------------+-----------+-----------+----------------+---------------+--------------+----------------------------------+--------------+------------------+------------+
# only showing top 20 rows

# %% [markdown]
# ## Question 15 — String functions
#
# Trim passenger_name and convert it to title case.
#
# **Functions/concepts:** `trim, initcap`

# %%
# TODO Question 15
# Write your PySpark solution below.

bookings_df.withColumn(
    "passenger_name",
    F.initcap(F.trim(F.col("passenger_name")))
).show(truncate=False)
# Out:
# +----------+--------------+------------+----------+-------------+----------+------------+-----------+-----------+----------------+---------------+--------------+----------------------------------+--------------+------------------+------------+
# |booking_id|passenger_name|airline_code|route_code|ticket_amount|baggage_kg|booking_date|travel_date|origin_city|destination_city|seat_class     |promo_discount|services                          |booking_status|satisfaction_score|payment_mode|
# +----------+--------------+------------+----------+-------------+----------+------------+-----------+-----------+----------------+---------------+--------------+----------------------------------+--------------+------------------+------------+
# |1001      |Aarav Mehta   |SKY         |BLR-DEL   |8500.0       |15.0      |2026-01-05  |2026-02-10 |Bengaluru  |Delhi           |Economy        |NULL          |Meal|WiFi                         |CONFIRMED     |4.5               |Card        |
# |1002      |Diya Iyer     |NVA         |DEL-BOM   |7200.0       |20.0      |2026-01-08  |2026-02-12 |Delhi      |Mumbai          |Economy        |500.0         |Meal|Priority Boarding            |CONFIRMED     |4.2               |UPI         |
# |1003      |Kabir Khan    |ORB         |MAA-HYD   |6400.0       |10.0      |2026-01-10  |2026-02-15 |Chennai    |Hyderabad       |Economy        |300.0         |WiFi                              |COMPLETED     |3.8               |Card        |
# |1004      |Meera Das     |ZEP         |BOM-GOA   |5100.0       |7.0       |2026-01-12  |2026-02-18 |Mumbai     |Goa             |Economy        |NULL          |Meal                              |CANCELLED     |NULL              |NetBanking  |
# |1005      |Nisha Roy     |LUM         |CCU-DEL   |9300.0       |22.0      |2026-01-15  |2026-02-20 |Kolkata    |Delhi           |Premium Economy|750.0         |Meal|WiFi|Lounge                  |CONFIRMED     |4.7               |UPI         |
# |1006      |Arjun Nair    |SKY         |BLR-MAA   |5800.0       |12.0      |2026-01-18  |2026-02-21 |Bengaluru  |Chennai         |Economy        |250.0         |Meal|WiFi                         |COMPLETED     |4.0               |Card        |
# |1007      |Sana Sheikh   |NVA         |HYD-BLR   |6900.0       |18.0      |2026-01-20  |2026-02-23 |Hyderabad  |Bengaluru       |Economy        |NULL          |Priority Boarding                 |CONFIRMED     |4.1               |Wallet      |
# |1008      |Rohan  Sen    |ORB         |DEL-JAI   |4300.0       |5.0       |2026-01-22  |2026-02-25 |Delhi      |Jaipur          |Economy        |200.0         |NULL                              |COMPLETED     |3.6               |UPI         |
# |1009      |Priya Kapoor  |ZEP         |BLR-DEL   |12500.0      |25.0      |2026-01-25  |2026-03-01 |Bengaluru  |Delhi           |Business       |1000.0        |Meal|WiFi|Lounge|Priority Boarding|CONFIRMED     |4.9               |Card        |
# |1010      |Vikas Jain    |LUM         |DEL-BOM   |11800.0      |24.0      |2026-01-28  |2026-03-03 |Delhi      |Mumbai          |Business       |NULL          |Meal|Lounge                       |CONFIRMED     |4.4               |NetBanking  |
# |1011      |Ananya Bose   |SKY         |MAA-HYD   |6100.0       |9.0       |2026-02-01  |2026-03-05 |Chennai    |Hyderabad       |Economy        |350.0         |Meal                              |COMPLETED     |4.0               |UPI         |
# |1012      |Karan Malhotra|NVA         |BOM-GOA   |5400.0       |8.0       |2026-02-02  |2026-03-06 |Mumbai     |Goa             |Economy        |NULL          |Meal|WiFi                         |CONFIRMED     |3.9               |Card        |
# |1012      |Karan Malhotra|NVA         |BOM-GOA   |5400.0       |8.0       |2026-02-02  |2026-03-06 |Mumbai     |Goa             |Economy        |NULL          |Meal|WiFi                         |CONFIRMED     |3.9               |Card        |
# |1013      |Ishita Paul   |ORB         |CCU-DEL   |8700.0       |16.0      |2026-02-04  |2026-03-08 |Kolkata    |Delhi           |Premium Economy|600.0         |Meal|WiFi                         |COMPLETED     |4.3               |Wallet      |
# |1014      |Mohan Rao     |ZEP         |BLR-MAA   |5900.0       |14.0      |2026-02-06  |2026-03-10 |Bengaluru  |Chennai         |Economy        |300.0         |Meal                              |CONFIRMED     |4.1               |UPI         |
# |1015      |Leena Joseph  |LUM         |HYD-BLR   |7600.0       |19.0      |2026-02-08  |2026-03-12 |Hyderabad  |Bengaluru       |Premium Economy|NULL          |WiFi|Priority Boarding            |CANCELLED     |3.5               |Card        |
# |1016      |Dev Patel     |SKY         |DEL-JAI   |4500.0       |6.0       |2026-02-10  |2026-03-14 |Delhi      |Jaipur          |Economy        |150.0         |Meal                              |COMPLETED     |3.7               |Cash        |
# |1017      |Kavya Reddy   |NVA         |BLR-DEL   |8500.0       |15.0      |2026-02-12  |2026-03-16 |Bengaluru  |Delhi           |Economy        |500.0         |Meal|WiFi                         |CONFIRMED     |4.6               |UPI         |
# |1018      |Rahul Verma   |ORB         |DEL-BOM   |7200.0       |20.0      |2026-02-14  |2026-03-18 |Delhi      |Mumbai          |Economy        |NULL          |Meal|Priority Boarding            |CONFIRMED     |4.0               |Card        |
# |1019      |Simran Kaur   |ZEP         |MAA-HYD   |6400.0       |11.0      |2026-02-16  |2026-03-20 |Chennai    |Hyderabad       |Economy        |250.0         |WiFi                              |COMPLETED     |3.8               |Wallet      |
# +----------+--------------+------------+----------+-------------+----------+------------+-----------+-----------+----------------+---------------+--------------+----------------------------------+--------------+------------------+------------+
# only showing top 20 rows

# %% [markdown]
# ## Question 16 — String functions
#
# Display passenger_name in uppercase, lowercase, and title case.
#
# **Functions/concepts:** `upper, lower, initcap`

# %%
# TODO Question 16
# Write your PySpark solution below.

bookings_df.select(
   F.col("passenger_name"),
   F.upper("passenger_name").alias("passenger_name_upper"),
   F.lower("passenger_name").alias("passenger_name_lower")
).show(truncate = False)
# Out:
# +----------------+--------------------+--------------------+
# |passenger_name  |passenger_name_upper|passenger_name_lower|
# +----------------+--------------------+--------------------+
# |  aarav mehta   |  AARAV MEHTA       |  aarav mehta       |
# |DIYA IYER       |DIYA IYER           |diya iyer           |
# |kabir khan      |KABIR KHAN          |kabir khan          |
# |Meera Das       |MEERA DAS           |meera das           |
# |  nisha roy     |  NISHA ROY         |  nisha roy         |
# |ARJUN NAIR      |ARJUN NAIR          |arjun nair          |
# |sana sheikh     |SANA SHEIKH         |sana sheikh         |
# |Rohan  Sen      |ROHAN  SEN          |rohan  sen          |
# |  priya kapoor  |  PRIYA KAPOOR      |  priya kapoor      |
# |VIKAS JAIN      |VIKAS JAIN          |vikas jain          |
# |ananya bose     |ANANYA BOSE         |ananya bose         |
# |Karan Malhotra  |KARAN MALHOTRA      |karan malhotra      |
# |Karan Malhotra  |KARAN MALHOTRA      |karan malhotra      |
# |  ishita paul   |  ISHITA PAUL       |  ishita paul       |
# |MOHAN RAO       |MOHAN RAO           |mohan rao           |
# |leena joseph    |LEENA JOSEPH        |leena joseph        |
# |Dev Patel       |DEV PATEL           |dev patel           |
# |  kavya reddy   |  KAVYA REDDY       |  kavya reddy       |
# |RAHUL VERMA     |RAHUL VERMA         |rahul verma         |
# |simran kaur     |SIMRAN KAUR         |simran kaur         |
# +----------------+--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ## Question 17 — String functions
#
# Calculate the length of each cleaned passenger name.
#
# **Functions/concepts:** `length, trim`

# %%
# TODO Question 17
# Write your PySpark solution below.
bookings_df.select(F.col("passenger_name"),
F.length(F.trim(F.col("passenger_name"))),
F.initcap(F.trim(F.col("passenger_name"))).alias("passenger_name_trimmed")).show(truncate = False)
# Out:
# +----------------+----------------------------+----------------------+
# |passenger_name  |length(trim(passenger_name))|passenger_name_trimmed|
# +----------------+----------------------------+----------------------+
# |  aarav mehta   |11                          |Aarav Mehta           |
# |DIYA IYER       |9                           |Diya Iyer             |
# |kabir khan      |10                          |Kabir Khan            |
# |Meera Das       |9                           |Meera Das             |
# |  nisha roy     |9                           |Nisha Roy             |
# |ARJUN NAIR      |10                          |Arjun Nair            |
# |sana sheikh     |11                          |Sana Sheikh           |
# |Rohan  Sen      |10                          |Rohan  Sen            |
# |  priya kapoor  |12                          |Priya Kapoor          |
# |VIKAS JAIN      |10                          |Vikas Jain            |
# |ananya bose     |11                          |Ananya Bose           |
# |Karan Malhotra  |14                          |Karan Malhotra        |
# |Karan Malhotra  |14                          |Karan Malhotra        |
# |  ishita paul   |11                          |Ishita Paul           |
# |MOHAN RAO       |9                           |Mohan Rao             |
# |leena joseph    |12                          |Leena Joseph          |
# |Dev Patel       |9                           |Dev Patel             |
# |  kavya reddy   |11                          |Kavya Reddy           |
# |RAHUL VERMA     |11                          |Rahul Verma           |
# |simran kaur     |11                          |Simran Kaur           |
# +----------------+----------------------------+----------------------+
# only showing top 20 rows

# %% [markdown]
# ## Question 18 — String functions
#
# Extract the first five characters of every cleaned passenger name. Remember Spark substring positions start at 1.
#
# **Functions/concepts:** `substring`

# %%
# TODO Question 18
# Write your PySpark solution below.

bookings_df.withColumn("passenger_name", F.substring(F.col("passenger_name"),1,5)).show(truncate = False)
# Out:
# +----------+--------------+------------+----------+-------------+----------+------------+-----------+-----------+----------------+---------------+--------------+----------------------------------+--------------+------------------+------------+
# |booking_id|passenger_name|airline_code|route_code|ticket_amount|baggage_kg|booking_date|travel_date|origin_city|destination_city|seat_class     |promo_discount|services                          |booking_status|satisfaction_score|payment_mode|
# +----------+--------------+------------+----------+-------------+----------+------------+-----------+-----------+----------------+---------------+--------------+----------------------------------+--------------+------------------+------------+
# |1001      |  aar         |SKY         |BLR-DEL   |8500.0       |15.0      |2026-01-05  |2026-02-10 |Bengaluru  |Delhi           |Economy        |NULL          |Meal|WiFi                         |CONFIRMED     |4.5               |Card        |
# |1002      |DIYA          |NVA         |DEL-BOM   |7200.0       |20.0      |2026-01-08  |2026-02-12 |Delhi      |Mumbai          |Economy        |500.0         |Meal|Priority Boarding            |CONFIRMED     |4.2               |UPI         |
# |1003      |kabir         |ORB         |MAA-HYD   |6400.0       |10.0      |2026-01-10  |2026-02-15 |Chennai    |Hyderabad       |Economy        |300.0         |WiFi                              |COMPLETED     |3.8               |Card        |
# |1004      |Meera         |ZEP         |BOM-GOA   |5100.0       |7.0       |2026-01-12  |2026-02-18 |Mumbai     |Goa             |Economy        |NULL          |Meal                              |CANCELLED     |NULL              |NetBanking  |
# |1005      |  nis         |LUM         |CCU-DEL   |9300.0       |22.0      |2026-01-15  |2026-02-20 |Kolkata    |Delhi           |Premium Economy|750.0         |Meal|WiFi|Lounge                  |CONFIRMED     |4.7               |UPI         |
# |1006      |ARJUN         |SKY         |BLR-MAA   |5800.0       |12.0      |2026-01-18  |2026-02-21 |Bengaluru  |Chennai         |Economy        |250.0         |Meal|WiFi                         |COMPLETED     |4.0               |Card        |
# |1007      |sana          |NVA         |HYD-BLR   |6900.0       |18.0      |2026-01-20  |2026-02-23 |Hyderabad  |Bengaluru       |Economy        |NULL          |Priority Boarding                 |CONFIRMED     |4.1               |Wallet      |
# |1008      |Rohan         |ORB         |DEL-JAI   |4300.0       |5.0       |2026-01-22  |2026-02-25 |Delhi      |Jaipur          |Economy        |200.0         |NULL                              |COMPLETED     |3.6               |UPI         |
# |1009      |  pri         |ZEP         |BLR-DEL   |12500.0      |25.0      |2026-01-25  |2026-03-01 |Bengaluru  |Delhi           |Business       |1000.0        |Meal|WiFi|Lounge|Priority Boarding|CONFIRMED     |4.9               |Card        |
# |1010      |VIKAS         |LUM         |DEL-BOM   |11800.0      |24.0      |2026-01-28  |2026-03-03 |Delhi      |Mumbai          |Business       |NULL          |Meal|Lounge                       |CONFIRMED     |4.4               |NetBanking  |
# |1011      |anany         |SKY         |MAA-HYD   |6100.0       |9.0       |2026-02-01  |2026-03-05 |Chennai    |Hyderabad       |Economy        |350.0         |Meal                              |COMPLETED     |4.0               |UPI         |
# |1012      |Karan         |NVA         |BOM-GOA   |5400.0       |8.0       |2026-02-02  |2026-03-06 |Mumbai     |Goa             |Economy        |NULL          |Meal|WiFi                         |CONFIRMED     |3.9               |Card        |
# |1012      |Karan         |NVA         |BOM-GOA   |5400.0       |8.0       |2026-02-02  |2026-03-06 |Mumbai     |Goa             |Economy        |NULL          |Meal|WiFi                         |CONFIRMED     |3.9               |Card        |
# |1013      |  ish         |ORB         |CCU-DEL   |8700.0       |16.0      |2026-02-04  |2026-03-08 |Kolkata    |Delhi           |Premium Economy|600.0         |Meal|WiFi                         |COMPLETED     |4.3               |Wallet      |
# |1014      |MOHAN         |ZEP         |BLR-MAA   |5900.0       |14.0      |2026-02-06  |2026-03-10 |Bengaluru  |Chennai         |Economy        |300.0         |Meal                              |CONFIRMED     |4.1               |UPI         |
# |1015      |leena         |LUM         |HYD-BLR   |7600.0       |19.0      |2026-02-08  |2026-03-12 |Hyderabad  |Bengaluru       |Premium Economy|NULL          |WiFi|Priority Boarding            |CANCELLED     |3.5               |Card        |
# |1016      |Dev P         |SKY         |DEL-JAI   |4500.0       |6.0       |2026-02-10  |2026-03-14 |Delhi      |Jaipur          |Economy        |150.0         |Meal                              |COMPLETED     |3.7               |Cash        |
# |1017      |  kav         |NVA         |BLR-DEL   |8500.0       |15.0      |2026-02-12  |2026-03-16 |Bengaluru  |Delhi           |Economy        |500.0         |Meal|WiFi                         |CONFIRMED     |4.6               |UPI         |
# |1018      |RAHUL         |ORB         |DEL-BOM   |7200.0       |20.0      |2026-02-14  |2026-03-18 |Delhi      |Mumbai          |Economy        |NULL          |Meal|Priority Boarding            |CONFIRMED     |4.0               |Card        |
# |1019      |simra         |ZEP         |MAA-HYD   |6400.0       |11.0      |2026-02-16  |2026-03-20 |Chennai    |Hyderabad       |Economy        |250.0         |WiFi                              |COMPLETED     |3.8               |Wallet      |
# +----------+--------------+------------+----------+-------------+----------+------------+-----------+-----------+----------------+---------------+--------------+----------------------------------+--------------+------------------+------------+
# only showing top 20 rows

# %% [markdown]
# ## Question 19 — String functions
#
# Create booking_code in the format BOOK-1001 by joining a literal and booking_id.
#
# **Functions/concepts:** `concat, lit, cast`

# %%
# TODO Question 19
# Write your PySpark solution below.
bookings_df.withColumn("booking_code", F.concat(F.lit("BOOK-"), F.col("booking_id").cast("string"))
).select("booking_id", "booking_code").show(truncate=False)
# Out:
# +----------+------------+
# |booking_id|booking_code|
# +----------+------------+
# |1001      |BOOK-1001   |
# |1002      |BOOK-1002   |
# |1003      |BOOK-1003   |
# |1004      |BOOK-1004   |
# |1005      |BOOK-1005   |
# |1006      |BOOK-1006   |
# |1007      |BOOK-1007   |
# |1008      |BOOK-1008   |
# |1009      |BOOK-1009   |
# |1010      |BOOK-1010   |
# |1011      |BOOK-1011   |
# |1012      |BOOK-1012   |
# |1012      |BOOK-1012   |
# |1013      |BOOK-1013   |
# |1014      |BOOK-1014   |
# |1015      |BOOK-1015   |
# |1016      |BOOK-1016   |
# |1017      |BOOK-1017   |
# |1018      |BOOK-1018   |
# |1019      |BOOK-1019   |
# +----------+------------+
# only showing top 20 rows

# %% [markdown]
# ## Question 20 — String functions
#
# Create booking_summary as Passenger - Airline - Route - Seat Class.
#
# **Functions/concepts:** `concat_ws`

# %%
# TODO Question 20
# Write your PySpark solution below.
bookings_df.withColumn("booking_summary", F.concat_ws(' - ',F.col("passenger_name"),F.col("airline_code"),F.col("route_code"),F.col("seat_class"))).select("booking_summary").show(truncate = False)
# Out:
# +-----------------------------------------------+
# |booking_summary                                |
# +-----------------------------------------------+
# |  aarav mehta   - SKY - BLR-DEL - Economy      |
# |DIYA IYER - NVA - DEL-BOM - Economy            |
# |kabir khan - ORB - MAA-HYD - Economy           |
# |Meera Das - ZEP - BOM-GOA - Economy            |
# |  nisha roy - LUM - CCU-DEL - Premium Economy  |
# |ARJUN NAIR - SKY - BLR-MAA - Economy           |
# |sana sheikh - NVA - HYD-BLR - Economy          |
# |Rohan  Sen - ORB - DEL-JAI - Economy           |
# |  priya kapoor   - ZEP - BLR-DEL - Business    |
# |VIKAS JAIN - LUM - DEL-BOM - Business          |
# |ananya bose - SKY - MAA-HYD - Economy          |
# |Karan Malhotra - NVA - BOM-GOA - Economy       |
# |Karan Malhotra - NVA - BOM-GOA - Economy       |
# |  ishita paul - ORB - CCU-DEL - Premium Economy|
# |MOHAN RAO - ZEP - BLR-MAA - Economy            |
# |leena joseph - LUM - HYD-BLR - Premium Economy |
# |Dev Patel - SKY - DEL-JAI - Economy            |
# |  kavya reddy   - NVA - BLR-DEL - Economy      |
# |RAHUL VERMA - ORB - DEL-BOM - Economy          |
# |simran kaur - ZEP - MAA-HYD - Economy          |
# +-----------------------------------------------+
# only showing top 20 rows

# %% [markdown]
# ## Question 21 — String functions
#
# Replace repeated spaces inside passenger_name with one space.
#
# **Functions/concepts:** `regexp_replace`

# %%
# TODO Question 21
# Write your PySpark solution below.
bookings_df.withColumn(
    "passenger_name",
    F.regexp_replace(F.col("passenger_name"), r"\s+", " ")
).select("passenger_name").show(truncate=False)
# Out:
# +--------------+
# |passenger_name|
# +--------------+
# | aarav mehta  |
# |DIYA IYER     |
# |kabir khan    |
# |Meera Das     |
# | nisha roy    |
# |ARJUN NAIR    |
# |sana sheikh   |
# |Rohan Sen     |
# | priya kapoor |
# |VIKAS JAIN    |
# |ananya bose   |
# |Karan Malhotra|
# |Karan Malhotra|
# | ishita paul  |
# |MOHAN RAO     |
# |leena joseph  |
# |Dev Patel     |
# | kavya reddy  |
# |RAHUL VERMA   |
# |simran kaur   |
# +--------------+
# only showing top 20 rows

# %% [markdown]
# ## Question 22 — String functions
#
# Split route_code into an array containing origin code and destination code.
#
# **Functions/concepts:** `split`

# %%
# TODO Question 22
# Write your PySpark solution below.
bookings_df.withColumn("route_array", F.split(F.col("route_code"), "-")).select("route_code", "route_array").show(truncate = False)
# Out:
# +----------+-----------+
# |route_code|route_array|
# +----------+-----------+
# |BLR-DEL   |[BLR, DEL] |
# |DEL-BOM   |[DEL, BOM] |
# |MAA-HYD   |[MAA, HYD] |
# |BOM-GOA   |[BOM, GOA] |
# |CCU-DEL   |[CCU, DEL] |
# |BLR-MAA   |[BLR, MAA] |
# |HYD-BLR   |[HYD, BLR] |
# |DEL-JAI   |[DEL, JAI] |
# |BLR-DEL   |[BLR, DEL] |
# |DEL-BOM   |[DEL, BOM] |
# |MAA-HYD   |[MAA, HYD] |
# |BOM-GOA   |[BOM, GOA] |
# |BOM-GOA   |[BOM, GOA] |
# |CCU-DEL   |[CCU, DEL] |
# |BLR-MAA   |[BLR, MAA] |
# |HYD-BLR   |[HYD, BLR] |
# |DEL-JAI   |[DEL, JAI] |
# |BLR-DEL   |[BLR, DEL] |
# |DEL-BOM   |[DEL, BOM] |
# |MAA-HYD   |[MAA, HYD] |
# +----------+-----------+
# only showing top 20 rows

# %% [markdown]
# ## Question 23 — String functions
#
# Find names containing 'an', origin cities starting with 'B', and destination cities ending with 'i'.
#
# **Functions/concepts:** `contains, startswith, endswith`

# %%
# TODO Question 23
# Write your PySpark solution below.
bookings_df.filter(
F.col("passenger_name").contains("an") &
F.col("origin_city").startswith("B") &
F.col("destination_city").endswith("i")
)
# Out:
# DataFrame[booking_id: bigint, passenger_name: string, airline_code: string, route_code: string, ticket_amount: double, baggage_kg: double, booking_date: string, travel_date: string, origin_city: string, destination_city: string, seat_class: string, promo_discount: double, services: string, booking_status: string, satisfaction_score: double, payment_mode: string]

# %% [markdown]
# ## Question 24 — Numeric functions
#
# Divide ticket_amount by 3 and show the rounded value (2 decimals), ceiling, and floor.
#
# **Functions/concepts:** `round, ceil, floor`

# %%
# TODO Question 24
# Write your PySpark solution below.
bookings_df.select(
   F.col("ticket_amount"),
   F.round(F.col("ticket_amount") / 3, 2).alias("rounded"),
   F.ceil(F.col("ticket_amount") / 3, 2).alias("ceiling"),
   F.floor(F.col("ticket_amount") / 3, 2).alias("floor")
).show(truncate = False)
# Out:
# +-------------+-------+-------+-------+
# |ticket_amount|rounded|ceiling|floor  |
# +-------------+-------+-------+-------+
# |8500.0       |2833.33|2833.34|2833.33|
# |7200.0       |2400.0 |2400.00|2400.00|
# |6400.0       |2133.33|2133.34|2133.33|
# |5100.0       |1700.0 |1700.00|1700.00|
# |9300.0       |3100.0 |3100.00|3100.00|
# |5800.0       |1933.33|1933.34|1933.33|
# |6900.0       |2300.0 |2300.00|2300.00|
# |4300.0       |1433.33|1433.34|1433.33|
# |12500.0      |4166.67|4166.67|4166.66|
# |11800.0      |3933.33|3933.34|3933.33|
# |6100.0       |2033.33|2033.34|2033.33|
# |5400.0       |1800.0 |1800.00|1800.00|
# |5400.0       |1800.0 |1800.00|1800.00|
# |8700.0       |2900.0 |2900.00|2900.00|
# |5900.0       |1966.67|1966.67|1966.66|
# |7600.0       |2533.33|2533.34|2533.33|
# |4500.0       |1500.0 |1500.00|1500.00|
# |8500.0       |2833.33|2833.34|2833.33|
# |7200.0       |2400.0 |2400.00|2400.00|
# |6400.0       |2133.33|2133.34|2133.33|
# +-------------+-------+-------+-------+
# only showing top 20 rows

# %% [markdown]
# ## Question 25 — Numeric functions
#
# Calculate the absolute difference between ticket_amount and a reference fare of 7,000.
#
# **Functions/concepts:** `abs`

# %%
# TODO Question 25
# Write your PySpark solution below.
bookings_df.select(
   F.col("ticket_amount"),
   F.abs(F.col("ticket_amount") - F.lit(7000)).alias("absolute difference from 7,000")
).show(truncate = False)
# Out:
# +-------------+------------------------------+
# |ticket_amount|absolute difference from 7,000|
# +-------------+------------------------------+
# |8500.0       |1500.0                        |
# |7200.0       |200.0                         |
# |6400.0       |600.0                         |
# |5100.0       |1900.0                        |
# |9300.0       |2300.0                        |
# |5800.0       |1200.0                        |
# |6900.0       |100.0                         |
# |4300.0       |2700.0                        |
# |12500.0      |5500.0                        |
# |11800.0      |4800.0                        |
# |6100.0       |900.0                         |
# |5400.0       |1600.0                        |
# |5400.0       |1600.0                        |
# |8700.0       |1700.0                        |
# |5900.0       |1100.0                        |
# |7600.0       |600.0                         |
# |4500.0       |2500.0                        |
# |8500.0       |1500.0                        |
# |7200.0       |200.0                         |
# |6400.0       |600.0                         |
# +-------------+------------------------------+
# only showing top 20 rows

# %% [markdown]
# ## Question 26 — Numeric functions
#
# Calculate baggage_kg squared.
#
# **Functions/concepts:** `pow`

# %%
# TODO Question 26
# Write your PySpark solution below.
bookings_df.select(
   F.col("baggage_kg"),
   F.pow(F.col("baggage_kg")).alias("Baggage^2")
).show(truncate = False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <command-5171890123932977>, line 5
#       1 # TODO Question 26
#       2 # Write your PySpark solution below.
#       3 bookings_df.select(
#       4    F.col("baggage_kg"),
# ----> 5    F.pow(F.col("baggage_kg")).alias("Baggage^2")
#       6 ).show(truncate = False)
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/utils.py:308, in try_remote_functions.<locals>.wrapped(*args, **kwargs)
#     305 if is_remote() and "PYSPARK_NO_NAMESPACE_SHARE" not in os.environ:
#     306     from pyspark.sql.connect import functions
# --> 308     return getattr(functions, f.__name__)(*args, **kwargs)
#     309 else:
#     310     return f(*args, **kwargs)
#
# TypeError: pow() missing 1 required positional argument: 'col2'

# %% [markdown]
# ## Question 27 — Numeric functions
#
# Calculate the square root of ticket_amount.
#
# **Functions/concepts:** `sqrt`

# %%
bookings_df.select(
   F.col("ticket_amount"),
    F.round(F.sqrt(F.col("ticket_amount")), 2).alias("ticket_sqrt")
).show(truncate = False)
# Out:
# +-------------+-----------+
# |ticket_amount|ticket_sqrt|
# +-------------+-----------+
# |8500.0       |92.2       |
# |7200.0       |84.85      |
# |6400.0       |80.0       |
# |5100.0       |71.41      |
# |9300.0       |96.44      |
# |5800.0       |76.16      |
# |6900.0       |83.07      |
# |4300.0       |65.57      |
# |12500.0      |111.8      |
# |11800.0      |108.63     |
# |6100.0       |78.1       |
# |5400.0       |73.48      |
# |5400.0       |73.48      |
# |8700.0       |93.27      |
# |5900.0       |76.81      |
# |7600.0       |87.18      |
# |4500.0       |67.08      |
# |8500.0       |92.2       |
# |7200.0       |84.85      |
# |6400.0       |80.0       |
# +-------------+-----------+
# only showing top 20 rows

# %% [markdown]
# ## Question 28 — Numeric functions
#
# Create fare_plus_tax, fare_after_flat_discount, doubled_baggage, and fare_per_kg using arithmetic operators. Use a safe divisor for zero baggage.
#
# **Functions/concepts:** `arithmetic operators, when`

# %%
# TODO Question 28
# Write your PySpark solution below.
bookings_df.select(
   F.col("ticket_amount"),
   F.col("baggage_kg"),
   (F.col("ticket_amount") * 1.18).alias("fare_plus_tax"),
   (F.col("ticket_amount") - F.lit(100)).alias("fare_after_flat_discount"),
   (F.col("ticket_amount") * 2).alias("double_baggage"),
   F.when(F.col("baggage_kg") == 0, None).otherwise(F.col("ticket_amount") / F.col("baggage_kg"))
   .alias("fare_per_kg")
).show(truncate = False)
# Out:
# +-------------+----------+-------------+------------------------+--------------+------------------+
# |ticket_amount|baggage_kg|fare_plus_tax|fare_after_flat_discount|double_baggage|fare_per_kg       |
# +-------------+----------+-------------+------------------------+--------------+------------------+
# |8500.0       |15.0      |10030.0      |8400.0                  |17000.0       |566.6666666666666 |
# |7200.0       |20.0      |8496.0       |7100.0                  |14400.0       |360.0             |
# |6400.0       |10.0      |7552.0       |6300.0                  |12800.0       |640.0             |
# |5100.0       |7.0       |6018.0       |5000.0                  |10200.0       |728.5714285714286 |
# |9300.0       |22.0      |10974.0      |9200.0                  |18600.0       |422.72727272727275|
# |5800.0       |12.0      |6844.0       |5700.0                  |11600.0       |483.3333333333333 |
# |6900.0       |18.0      |8142.0       |6800.0                  |13800.0       |383.3333333333333 |
# |4300.0       |5.0       |5074.0       |4200.0                  |8600.0        |860.0             |
# |12500.0      |25.0      |14750.0      |12400.0                 |25000.0       |500.0             |
# |11800.0      |24.0      |13924.0      |11700.0                 |23600.0       |491.6666666666667 |
# |6100.0       |9.0       |7198.0       |6000.0                  |12200.0       |677.7777777777778 |
# |5400.0       |8.0       |6372.0       |5300.0                  |10800.0       |675.0             |
# |5400.0       |8.0       |6372.0       |5300.0                  |10800.0       |675.0             |
# |8700.0       |16.0      |10266.0      |8600.0                  |17400.0       |543.75            |
# |5900.0       |14.0      |6962.0       |5800.0                  |11800.0       |421.42857142857144|
# |7600.0       |19.0      |8968.0       |7500.0                  |15200.0       |400.0             |
# |4500.0       |6.0       |5310.0       |4400.0                  |9000.0        |750.0             |
# |8500.0       |15.0      |10030.0      |8400.0                  |17000.0       |566.6666666666666 |
# |7200.0       |20.0      |8496.0       |7100.0                  |14400.0       |360.0             |
# |6400.0       |11.0      |7552.0       |6300.0                  |12800.0       |581.8181818181819 |
# +-------------+----------+-------------+------------------------+--------------+------------------+
# only showing top 20 rows

# %% [markdown]
# ## Question 29 — Conditional logic
#
# Create fare_category: PREMIUM for fare >= 10,000; STANDARD for fare >= 6,000; otherwise BUDGET.
#
# **Functions/concepts:** `when, otherwise`

# %%
# TODO Question 29
# Write your PySpark solution below.

# %% [markdown]
# ## Question 30 — Null handling
#
# Display records where promo_discount is null and records where it is not null.
#
# **Functions/concepts:** `isNull, isNotNull`

# %%
# TODO Question 30
# Write your PySpark solution below.
bookings_df.fillna({"promo_discount": 0}).select("booking_id", "promo_discount").show(truncate = False)

# %% [markdown]
# ## Question 31 — Null handling
#
# Replace null promo_discount values with 0 using fillna().
#
# **Functions/concepts:** `fillna`

# %%
# TODO Question 31
# Write your PySpark solution below.
bookings_df.fillna({"promo_discount": 0}).select(
    "booking_id",
    F.format_number(F.col("promo_discount"), 2).alias("promo_discount")
).show(truncate=False)

# %% [markdown]
# ## Question 32 — Null handling
#
# Remove rows with null satisfaction_score.
#
# **Functions/concepts:** `dropna`

# %%
# TODO Question 32
# Write your PySpark solution below.

bookings_df.dropna(subset=["satisfaction_score"]).show(truncate = False)

# %% [markdown]
# ## Question 33 — Null handling
#
# Create final_discount using promo_discount when available, otherwise 0.
#
# **Functions/concepts:** `F.coalesce`

# %%
# TODO Question 33
# Write your PySpark solution below.
bookings_df.withColumn("final_discount", F.coalesce(F.col("promo_discount"), F.lit(0))).select("promo_discount", "final_discount").show(truncate = False)

# %% [markdown]
# ## Question 34 — Data type conversion
#
# Cast booking_id to string, satisfaction_score to integer, and ticket_amount to decimal(10,2). Print the resulting schema.
#
# **Functions/concepts:** `cast`

# %%
# TODO Question 34
# Write your PySpark solution below.
castedDF = bookings_df.withColumn(
   "booking_id", F.col("booking_id").cast("string")).withColumn("satisfaction_score", F.col("satisfaction_score").cast("integer")).withColumn("ticket_amount",F.col("ticket_amount").cast("decimal(10,2)"))

castedDF.printSchema()

# %% [markdown]
# ## Question 35 — Date functions
#
# Convert booking_date and travel_date from strings to DateType columns.
#
# **Functions/concepts:** `to_date`

# %%
# TODO Question 35
# Write your PySpark solution below.
castedDF = bookings_df.withColumn(
   "booking_id", F.col("booking_id").cast("string")).withColumn("satisfaction_score", F.col("satisfaction_score").cast("integer")).withColumn("ticket_amount",F.col("ticket_amount").cast("decimal(10,2)"))

castedDF.printSchema()

# %% [markdown]
# ## Question 36 — Date functions
#
# Add current_date and current_timestamp columns.
#
# **Functions/concepts:** `current_date, current_timestamp`

# %%
# TODO Question 36
# Write your PySpark solution below.
bookings_df.withColumn(
   "current_date",
   F.current_date()
).withColumn(
   "current_timestamp",
   F.current_timestamp()
).select(
   "booking_id",
   "current_date",
   "current_timestamp"
).show(truncate = False)

# %% [markdown]
# ## Question 37 — Date functions
#
# Extract travel year, month, day of month, and day of week.
#
# **Functions/concepts:** `year, month, dayofmonth, dayofweek`

# %%
# TODO Question 37
# Write your PySpark solution below.
datesDF.select( F.col("travel_data"),
   F.year(F.col("travel_date")).alias("travel_year"),
   F.month(F.col("travel_date")).alias("travel_month"),
   F.dayofmonth(F.col("travel_date")).alias("travel_day"),
   F.dayofweek(F.col("travel_date")).alias("travel_dayofweek")
).show(truncate = False)

# %% [markdown]
# ## Question 38 — Date functions
#
# Format travel_date as dd-MMM-yyyy.
#
# **Functions/concepts:** `date_format`

# %%
# TODO Question 38
# Write your PySpark solution below.
bookings_df.select(
   F.date_format(F.to_date(F.col("travel_date"), "yyyy-MM-dd"),
    "dd-MM-yyyy"
    ).alias("travel_date_formatted")
).show(truncate = False)

# %% [markdown]
# ## Question 39 — Date functions
#
# Calculate booking lead time in days and the months elapsed from booking_date to the current date.
#
# **Functions/concepts:** `datediff, months_between`

# %%
# TODO Question 39
# Write your PySpark solution below.
datesDF.select(
   "booking_date",
   "travel_date",
   F.datediff(F.col("travel_date"), F.col("booking_date")).alias("lead_time_in_days"),
   F.months_between(F.current_date(), F.col("booking_date")).alias("months_since_booking")
).show(truncate = False)

# %% [markdown]
# ## Question 40 — Date functions
#
# Create travel_plus_2_months, travel_plus_7_days, and travel_minus_3_days.
#
# **Functions/concepts:** `add_months, date_add, date_sub`

# %%
# TODO Question 40
# Write your PySpark solution below.
datesDF.select(
   F.col("travel_date"),
   F.add_months(F.col("travel_date"),2).alias("travel_plus_2_months"),
   F.date_add(F.col("travel_date"), 7).alias("travel_plus_7_days"),
   F.date_sub(F.col("travel_date"),3).alias("travel_minute_3_days")
).show(truncate = False)

# %% [markdown]
# ## Question 41 — Aggregations
#
# Produce one row containing booking count, total fare, average fare, minimum fare, maximum fare, and distinct airline count.
#
# **Functions/concepts:** `count, sum, avg, min, max, countDistinct`

# %%
bookings_df.agg(
    F.count("*").alias("booking_count"),
    F.sum("ticket_amount").alias("total_fare"),
    F.round(F.avg("ticket_amount"), 2).alias("average_fare"),
    F.min("ticket_amount").alias("minimum_fare"),
    F.max("ticket_amount").alias("maximum_fare"),
    F.countDistinct("airline_code").alias("distinct_airlines")
).show(truncate=False)

# %% [markdown]
# ## Question 42 — Aggregations
#
# Create an airline-level report with booking count, average fare, total fare, minimum fare, and maximum fare.
#
# **Functions/concepts:** `groupBy, agg`

# %%
# TODO Question 42
# Write your PySpark solution below.
bookings_df.groupBy("airline_code").agg(
    F.count("*").alias("booking_count"),
    F.round(F.avg("ticket_amount"), 2).alias("avg_fare"),
    F.sum("ticket_amount").alias("total_fare"),
    F.min("ticket_amount").alias("min_fare"),
    F.max("ticket_amount").alias("max_fare")
).show(truncate=False)

# %% [markdown]
# ## Question 43 — Aggregations
#
# For each seat_class, collect all booking statuses and the unique payment modes.
#
# **Functions/concepts:** `collect_list, collect_set`

# %%
# TODO Question 43
# Write your PySpark solution below.

bookings_df.groupBy("seat_class").agg(
   F.collect_list("booking_status").alias("all_statuses"),
   F.collect_set("payment_mode").alias("unique_payment_modes")
).show(truncate = False)

# %% [markdown]
# ## Question 44 — Sorting
#
# Sort bookings by ticket_amount ascending and then descending.
#
# **Functions/concepts:** `orderBy, asc, desc`

# %%
# TODO Question 44
# Write your PySpark solution below.
bookings_df.select(F.col("ticket_amount").alias("ascending_ticket_amount")).orderBy(F.col("ticket_amount").asc()).show(truncate = False)
bookings_df.select(F.col("ticket_amount").alias("descending_ticket_amount")).orderBy(F.col("ticket_amount").desc()).show(truncate = False)

# %% [markdown]
# ## Question 45 — Sorting
#
# Sort by airline_code ascending and ticket_amount descending.
#
# **Functions/concepts:** `multi-column orderBy`

# %%
# TODO Question 45
# Write your PySpark solution below.
bookings_df.select(F.col("airline_code").alias("ascending_airline_codoe")).orderBy(F.col("airline_code").asc()).show(truncate = False)
bookings_df.select(F.col("airline_code").alias("descending_airline_codoe")).orderBy(F.col("airline_code").desc()).show(truncate = False)

# %% [markdown]
# ## Question 46 — Sorting
#
# Display the top five most expensive bookings.
#
# **Functions/concepts:** `limit`

# %%
join_df = bookings_df.join(airline_df, bookings_df["airline_code"] == airline_df["airline_code"])
join_df.show(truncate = False)

# %% [markdown]
# ## Question 47 — Joins
#
# Perform an inner join between bookings_df and airline_df using airline_code.
#
# **Functions/concepts:** `inner join`

# %%
left_join_df = bookings_df.join(airline_df, bookings_df["airline_code"] == airline_df["airline_code"], how = "left")
left_join_df.show(truncate = False)

# %% [markdown]
# ## Question 48 — Joins
#
# Perform a left join and identify bookings whose airline is missing from the master.
#
# **Functions/concepts:** `left join`

# %%
# TODO Question 48
# Write your PySpark solution below.
left_join_df = bookings_df.join(airline_df, bookings_df["airline_code"] == airline_df["airline_code"], how = "left")
left_join_df.show(truncate = False)

# %% [markdown]
# ## Question 49 — Joins
#
# Perform a right join so that airlines with no bookings are also visible.
#
# **Functions/concepts:** `right join`

# %%
# TODO Question 49
# Write your PySpark solution below.
right_join_df = bookings_df.join(airline_df, bookings_df["airline_code"] == airline_df["airline_code"], how = "right")

right_join_df.show(truncate = False)

# %% [markdown]
# ## Question 50 — Joins
#
# Perform a full join and inspect both unmatched booking and airline records.
#
# **Functions/concepts:** `full join`

# %%
# TODO Question 50
# Write your PySpark solution below.
full_join_df = bookings_df.join(airline_df, bookings_df["airline_code"] ==  airline_df["airline_code"], how="full")
full_join_df.show(truncate = False)

# %% [markdown]
# ## Question 51 — Joins
#
# Use a left_semi join to return bookings having a valid airline code.
#
# **Functions/concepts:** `left_semi`

# %%
left_semi_join_df = bookings_df.join(airline_df, bookings_df["airline_code"] == airline_df["airline_code"], how = "left_semi")

left_semi_join_df.show(truncate = False)

# %% [markdown]
# ## Question 52 — Joins
#
# Use a left_anti join to return bookings having an invalid airline code.
#
# **Functions/concepts:** `left_anti`

# %%
left_anti_join_df = bookings_df.join(airline_df, bookings_df["airline_code"] == airline_df["airline_code"], how = "left_anti")

left_anti_join_df.show(truncate = False)

# %% [markdown]
# ## Question 53 — Joins
#
# Create a small seat-class reference DataFrame and cross join it with the list of airline codes.
#
# **Functions/concepts:** `cross join`

# %%
left_anti_join_df = bookings_df.join(airline_df, bookings_df["airline_code"] == airline_df["airline_code"], how = "cross")

left_anti_join_df.show(truncate = False)

# %% [markdown]
# ## Question 54 — Union
#
# Reorder the columns of new_bookings_df and append it to bookings_df using unionByName().
#
# **Functions/concepts:** `unionByName`

# %%
# TODO Question 54
# Write your PySpark solution below.
# Declare updated_bookings_df
updated_bookings_df = new_bookings_df.select(
    "payment_mode",
    "seat_class",
    "passenger_name",
    "booking_id",
    "airline_code",
    "route_code",
    "ticket_amount",
    "baggage_kg",
    "booking_date",
    "travel_date",
    "origin_city",
    "destination_city",
    "promo_discount",
    "services",
    "booking_status",
    "satisfaction_score"
)
# Append by column name
union_df = bookings_df.unionByName(updated_bookings_df)

# Display count of union_df
print(union_df.count()) 

# Display content of union_df
union_df.show(truncate=False)

# %% [markdown]
# ## Question 55 — Spark SQL
#
# Register bookings_df, airline_df, and route_df as temporary views.
#
# **Functions/concepts:** `createOrReplaceTempView`

# %%
bookings_df.createOrReplaceTempView("bookings")
airline_df.createOrReplaceTempView("airlines")
route_df.createOrReplaceTempView("routes")

spark.sql("SELECT * FROM bookings LIMIT 5").show(truncate = False)
spark.sql("SELECT * FROM airlines LIMIT 5").show(truncate = False)
spark.sql("SELECT * FROM routes LIMIT 5").show(truncate = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <command-5171890123933035>, line 1
# ----> 1 bookings_df.createOrReplaceTempView("bookings")
#       2 airline_df.createOrReplaceTempView("airlines")
#       3 route_df.createOrReplaceTempView("routes")
#
# NameError: name 'bookings_df' is not defined

# %% [markdown]
# ## Question 56 — Spark SQL
#
# Write SQL to display confirmed bookings above 8,000 ordered by fare descending.
#
# **Functions/concepts:** `spark.sql, WHERE, ORDER BY`

# %%
spark.sql("""
select * from bookings
          where booking_status = 'CONFIRMED'
          AND ticket_amount > 8000
          ORDER BY ticket_amount DESC
          """).show(truncate = False)
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-5171890123933037>, line 1
# ----> 1 spark.sql("""
#       2 select * from bookings
#       3           where booking_status = 'CONFIRMED'
#       4           AND ticket_amount > 8000
#       5           ORDER BY ticket_amount DESC
#       6           """).show(truncate = False)
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/session.py:901, in SparkSession.sql(self, sqlQuery, args, **kwargs)
#     898         _views.append(SubqueryAlias(df._plan, name))
#     900 cmd = SQL(sqlQuery, _args, _named_args, _views)
# --> 901 data, properties, ei = self.client.execute_command(cmd.command(self._client))
#     902 if "sql_command_result" in properties:
#     903     df = DataFrame(CachedRelation(properties["sql_command_result"]), self)
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py:1538, in SparkConnectClient.execute_command(self, command, observations, extra_request_metadata)
#    1536     req.user_context.user_id = self._user_id
#    1537 self._set_command_in_plan(req.plan, command)
# -> 1538 data, _, metrics, observed_metrics, properties = self._execute_and_fetch(
#    1539     req, observations or {}, extra_request_metadata
#    1540 )
#    1541 # Create a query execution object.
#    1542 ei = ExecutionInfo(metrics, observed_metrics)
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py:2086, in SparkConnectClient._execute_and_fetch(self, req, observations, extra_request_metadata, self_destruct)
#    2083 properties: Dict[str, Any] = {}
#    2085 with Progress(handlers=self._progress_handlers, operation_id=req.operation_id) as progress:
# -> 2086     for response in self._execute_and_fetch_as_iterator(
#    2087         req, observations, extra_request_metadata or [], progress=progress
#    2088     ):
#    2089         if isinstance(response, StructType):
#    2090             schema = response
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py:2062, in SparkConnectClient._execute_and_fetch_as_iterator(self, req, observations, extra_request_metadata, progress)
#    2060     raise kb
#    2061 except Exception as error:
# -> 2062     self._handle_error(error)
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py:2380, in SparkConnectClient._handle_error(self, error)
#    2378     self.thread_local.inside_error_handling = True
#    2379     if isinstance(error, grpc.RpcError):
# -> 2380         self._handle_rpc_error(error)
#    2381     raise error
#    2382 finally:
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py:2458, in SparkConnectClient._handle_rpc_error(self, rpc_error)
#    2454             logger.debug(f"Received ErrorInfo: {info}")
#    2456             self._handle_rpc_error_with_error_info(info, status.message, status_code)  # EDGE
# -> 2458             raise convert_exception(
#    2459                 info,
#    2460                 status.message,
#    2461                 self._fetch_enriched_error(info),
#    2462                 self._display_server_stack_trace(),
#    2463                 status_code,
#    2464             ) from None
#    2466     raise SparkConnectGrpcException(
#    2467         message=status.message,
#    2468         sql_state=ErrorCode.CLIENT_UNEXPECTED_MISSING_SQL_STATE,  # EDGE
#    2469         grpc_status_code=status_code,
#    2470     ) from None
#    2471 else:
#
# AnalysisException: [TABLE_OR_VIEW_NOT_FOUND] The table or view `bookings` cannot be found. Verify the spelling and correctness of the schema and catalog.
# Search path: [`system`.`session`, `system`.`builtin`, `system`.`ai`, `workspace`.`default`].
# If you did not qualify the name with a schema, verify the current_schema() output, or qualify the name with the correct schema and catalog.
# To tolerate the error on drop use DROP VIEW IF EXISTS or DROP TABLE IF EXISTS. SQLSTATE: 42P01; line 2 pos 14;
# 'Sort ['ticket_amount DESC NULLS LAST], true
# +- 'Project [*]
#    +- 'Filter (('booking_status = CONFIRMED) AND ('ticket_amount > 8000))
#       +- 'UnresolvedRelation [bookings], [], false
#
#
# JVM stacktrace:
# org.apache.spark.sql.catalyst.ExtendedAnalysisException
# 	at org.apache.spark.sql.errors.QueryCompilationErrors$.tableOrViewNotFoundWithSearchPath(QueryCompilationErrors.scala:1464)
# 	at org.apache.spark.sql.catalyst.analysis.package$AnalysisErrorAt.tableNotFound(package.scala:97)
# 	at org.apache.spark.sql.catalyst.analysis.RelationResolution$.throwTableNotFound(RelationResolution.scala:1806)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.$anonfun$checkAnalysis0$2(CheckAnalysis.scala:467)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.$anonfun$checkAnalysis0$2$adapted(CheckAnalysis.scala:410)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.foreachUp(TreeNode.scala:392)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.$anonfun$foreachUp$1(TreeNode.scala:391)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.$anonfun$foreachUp$1$adapted(TreeNode.scala:391)
# 	at scala.collection.immutable.Vector.foreach(Vector.scala:2125)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.foreachUp(TreeNode.scala:391)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.$anonfun$foreachUp$1(TreeNode.scala:391)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.$anonfun$foreachUp$1$adapted(TreeNode.scala:391)
# 	at scala.collection.immutable.Vector.foreach(Vector.scala:2125)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.foreachUp(TreeNode.scala:391)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.$anonfun$foreachUp$1(TreeNode.scala:391)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.$anonfun$foreachUp$1$adapted(TreeNode.scala:391)
# 	at scala.collection.immutable.Vector.foreach(Vector.scala:2125)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.foreachUp(TreeNode.scala:391)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.checkAnalysis0(CheckAnalysis.scala:410)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.checkAnalysis0$(CheckAnalysis.scala:377)
# 	at org.apache.spark.sql.catalyst.analysis.Analyzer.checkAnalysis0(Analyzer.scala:636)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.$anonfun$checkAnalysis$1(CheckAnalysis.scala:362)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.spark.util.FrameProfiler$.$anonfun$record$1(FrameProfiler.scala:114)
# 	at com.databricks.spark.util.FrameProfilerExporter$.maybeExportFrameProfiler(FrameProfilerExporter.scala:201)
# 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:105)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.checkAnalysis(CheckAnalysis.scala:349)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.checkAnalysis$(CheckAnalysis.scala:345)
# 	at org.apache.spark.sql.catalyst.analysis.Analyzer.checkAnalysis(Analyzer.scala:636)
# 	at org.apache.spark.sql.catalyst.analysis.resolver.HybridAnalyzer.$anonfun$resolveInFixedPoint$1(HybridAnalyzer.scala:417)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at org.apache.spark.sql.catalyst.QueryPlanningTracker$.withTracker(QueryPlanningTracker.scala:275)
# 	at org.apache.spark.sql.catalyst.analysis.resolver.HybridAnalyzer.resolveInFixedPoint(HybridAnalyzer.scala:417)
# 	at org.apache.spark.sql.catalyst.analysis.resolver.HybridAnalyzer.$anonfun$apply$1(HybridAnalyzer.scala:98)
# 	at org.apache.spark.sql.catalyst.analysis.resolver.HybridAnalyzer.withTrackedAnalyzerBridgeState(HybridAnalyzer.scala:135)
# 	at org.apache.spark.sql.catalyst.analysis.resolver.HybridAnalyzer.apply(HybridAnalyzer.scala:91)
# 	at org.apache.spark.sql.catalyst.analysis.Analyzer.$anonfun$executeAndCheck$2(Analyzer.scala:703)
# 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper$.markInAnalyzer(AnalysisHelper.scala:425)
# 	at org.apache.spark.sql.catalyst.analysis.Analyzer.$anonfun$executeAndCheck$1(Analyzer.scala:703)
# 	at com.databricks.sql.unity.SAMSnapshotHelper$.visitPlansDuringAnalysis(SAMSnapshotHelper.scala:43)
# 	at org.apache.spark.sql.catalyst.analysis.Analyzer.executeAndCheck(Analyzer.scala:692)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$lazyAnalyzed$3(QueryExecution.scala:607)
# 	at com.databricks.spark.util.FrameProfiler$.$anonfun$record$1(FrameProfiler.scala:114)
# 	at com.databricks.spark.util.FrameProfilerExporter$.maybeExportFrameProfiler(FrameProfilerExporter.scala:201)
# 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:105)
# 	at org.apache.spark.sql.catalyst.QueryPlanningTracker.measurePhase(QueryPlanningTracker.scala:1021)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$8(QueryExecution.scala:1073)
# 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withExecutionPhase$1(SQLExecution.scala:337)
# 	at com.databricks.util.TracingSpanUtils$.withTracing(TracingSpanUtils.scala:251)
# 	at com.databricks.spark.util.DatabricksTracingHelper.withSpan(DatabricksSparkTracingHelper.scala:154)
# 	at com.databricks.spark.util.DBRTracing$.withSpan(DBRTracing.scala:87)
# 	at org.apache.spark.sql.execution.SQLExecution$.withExecutionPhase(SQLExecution.scala:318)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$7(QueryExecution.scala:1073)
# 	at org.apache.spark.sql.execution.QueryExecution$.withInternalError(QueryExecution.scala:1822)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$5(QueryExecution.scala:1066)
# 	at com.databricks.util.LexicalThreadLocal$Handle.runWith(LexicalThreadLocal.scala:63)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$4(QueryExecution.scala:1063)
# 	at com.databricks.util.LexicalThreadLocal$Handle.runWith(LexicalThreadLocal.scala:63)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$3(QueryExecution.scala:1063)
# 	at com.databricks.util.LexicalThreadLocal$Handle.runWith(LexicalThreadLocal.scala:63)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$2(QueryExecution.scala:1062)
# 	at com.databricks.util.LexicalThreadLocal$Handle.runWith(LexicalThreadLocal.scala:63)
# 	at org.apache.spark.sql.execution.QueryExecution.localBlock$1(QueryExecution.scala:1043)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$withQueryExecutionId$4(QueryExecution.scala:1053)
# 	at com.databricks.unity.UCSManager$.withTemporaryScope(UCSManager.scala:168)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$withQueryExecutionId$3(QueryExecution.scala:1052)
# 	at org.apache.spark.sql.execution.QueryExecution$.$anonfun$runWithWrappers$2(QueryExecution.scala:2075)
# 	at org.apache.spark.sql.execution.QueryExecution$.org$apache$spark$sql$execution$QueryExecution$$runWithWrappers(QueryExecution.scala:2074)
# 	at org.apache.spark.sql.execution.QueryExecution.withQueryExecutionId(QueryExecution.scala:1053)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$1(QueryExecution.scala:1061)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:866)
# 	at org.apache.spark.sql.execution.QueryExecution.executePhase(QueryExecution.scala:1060)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$lazyAnalyzed$2(QueryExecution.scala:598)
# 	at com.databricks.sql.util.MemoryTrackerHelper.withMemoryTracking(MemoryTrackerHelper.scala:111)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$lazyAnalyzed$1(QueryExecution.scala:597)
# 	at scala.util.Try$.apply(Try.scala:217)
# 	at org.apache.spark.util.Utils$.doTryWithCallerStacktrace(Utils.scala:1796)
# 	at org.apache.spark.util.Utils$.getTryWithCallerStacktrace(Utils.scala:1846)
# 	at org.apache.spark.util.LazyTry.get(LazyTry.scala:78)
# 	at org.apache.spark.sql.execution.QueryExecution.analyzed(QueryExecution.scala:661)
# 	at org.apache.spark.sql.execution.QueryExecution.assertAnalyzed(QueryExecution.scala:520)
# 	at org.apache.spark.sql.classic.Dataset$.$anonfun$ofRows$3(Dataset.scala:157)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:866)
# 	at org.apache.spark.sql.classic.SparkSession.$anonfun$withActiveAndFrameProfiler$1(SparkSession.scala:1332)
# 	at com.databricks.spark.util.FrameProfiler$.$anonfun$record$1(FrameProfiler.scala:114)
# 	at com.databricks.spark.util.FrameProfilerExporter$.maybeExportFrameProfiler(FrameProfilerExporter.scala:201)
# 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:105)
# 	at org.apache.spark.sql.classic.SparkSession.withActiveAndFrameProfiler(SparkSession.scala:1332)
# 	at org.apache.spark.sql.classic.Dataset$.ofRows(Dataset.scala:149)
# 	at org.apache.spark.sql.classic.SparkSession.$anonfun$sql$6(SparkSession.scala:1017)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:866)
# 	at org.apache.spark.sql.classic.SparkSession.sql(SparkSession.scala:982)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.executeSQL(SparkConnectPlanner.scala:4303)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.handleSqlCommand(SparkConnectPlanner.scala:4096)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.process(SparkConnectPlanner.scala:3790)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.handleCommand(ExecuteThreadRunner.scala:530)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.$anonfun$executeInternal$1(ExecuteThreadRunner.scala:420)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.$anonfun$executeInternal$1$adapted(ExecuteThreadRunner.scala:340)
# 	at org.apache.spark.sql.connect.service.SessionHolder.$anonfun$withSession$2(SessionHolder.scala:844)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:866)
# 	at org.apache.spark.sql.connect.service.SessionHolder.$anonfun$withSession$1(SessionHolder.scala:844)
# 	at org.apache.spark.JobArtifactSet$.withActiveJobArtifactState(JobArtifactSet.scala:97)
# 	at org.apache.spark.sql.artifact.ArtifactManager.$anonfun$withResources$1(ArtifactManager.scala:124)
# 	at org.apache.spark.sql.artifact.ArtifactManager.withClassLoaderIfNeeded(ArtifactManager.scala:118)
# 	at org.apache.spark.sql.artifact.ArtifactManager.withResources(ArtifactManager.scala:123)
# 	at org.apache.spark.sql.connect.service.SessionHolder.withSession(SessionHolder.scala:843)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.executeInternal(ExecuteThreadRunner.scala:340)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.$anonfun$execute$1(ExecuteThreadRunner.scala:200)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.spark.connect.service.UtilizationMetrics.recordActiveQueries(UtilizationMetrics.scala:92)
# 	at com.databricks.spark.connect.service.UtilizationMetrics.recordActiveQueries$(UtilizationMetrics.scala:89)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.recordActiveQueries(ExecuteThreadRunner.scala:61)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.org$apache$spark$sql$connect$execution$ExecuteThreadRunner$$execute(ExecuteThreadRunner.scala:192)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner$ExecutionThread.$anonfun$run$3(ExecuteThreadRunner.scala:601)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.spark.util.DBRTracing$.withSpanFromParent(DBRTracing.scala:70)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner$ExecutionThread.$anonfun$run$2(ExecuteThreadRunner.scala:601)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.unity.UCSEphemeralState$Handle.runWith(UCSEphemeralState.scala:51)
# 	at com.databricks.unity.HandleImpl.runWith(UCSHandle.scala:128)
# 	at com.databricks.unity.HandleImpl.$anonfun$runWithAndClose$1(UCSHandle.scala:133)
# 	at scala.util.Using$.resource(Using.scala:296)
# 	at com.databricks.unity.HandleImpl.runWithAndClose(UCSHandle.scala:132)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner$ExecutionThread.run(ExecuteThreadRunner.scala:600)

# %% [markdown]
# ## Question 57 — Spark SQL
#
# Use SQL string functions to clean and format passenger names and calculate name length.
#
# **Functions/concepts:** `TRIM, UPPER, LOWER, INITCAP, LENGTH`

# %%
spark.sql("""
    SELECT
        passenger_name AS `Original name`,
        TRIM(passenger_name) AS `Trimmed name`,
        UPPER(TRIM(passenger_name)) AS `Upper name`,
        LOWER(TRIM(passenger_name)) AS `Lower name`,
        INITCAP(TRIM(passenger_name)) AS `Title name`,
        LENGTH(TRIM(passenger_name)) AS `Length of name`
    FROM bookings
""").show(truncate=False)
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-5171890123933039>, line 1
# ----> 1 spark.sql("""
#       2     SELECT
#       3         passenger_name AS `Original name`,
#       4         TRIM(passenger_name) AS `Trimmed name`,
#       5         UPPER(TRIM(passenger_name)) AS `Upper name`,
#       6         LOWER(TRIM(passenger_name)) AS `Lower name`,
#       7         INITCAP(TRIM(passenger_name)) AS `Title name`,
#       8         LENGTH(TRIM(passenger_name)) AS `Length of name`
#       9     FROM bookings
#      10 """).show(truncate=False)
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/session.py:901, in SparkSession.sql(self, sqlQuery, args, **kwargs)
#     898         _views.append(SubqueryAlias(df._plan, name))
#     900 cmd = SQL(sqlQuery, _args, _named_args, _views)
# --> 901 data, properties, ei = self.client.execute_command(cmd.command(self._client))
#     902 if "sql_command_result" in properties:
#     903     df = DataFrame(CachedRelation(properties["sql_command_result"]), self)
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py:1538, in SparkConnectClient.execute_command(self, command, observations, extra_request_metadata)
#    1536     req.user_context.user_id = self._user_id
#    1537 self._set_command_in_plan(req.plan, command)
# -> 1538 data, _, metrics, observed_metrics, properties = self._execute_and_fetch(
#    1539     req, observations or {}, extra_request_metadata
#    1540 )
#    1541 # Create a query execution object.
#    1542 ei = ExecutionInfo(metrics, observed_metrics)
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py:2086, in SparkConnectClient._execute_and_fetch(self, req, observations, extra_request_metadata, self_destruct)
#    2083 properties: Dict[str, Any] = {}
#    2085 with Progress(handlers=self._progress_handlers, operation_id=req.operation_id) as progress:
# -> 2086     for response in self._execute_and_fetch_as_iterator(
#    2087         req, observations, extra_request_metadata or [], progress=progress
#    2088     ):
#    2089         if isinstance(response, StructType):
#    2090             schema = response
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py:2062, in SparkConnectClient._execute_and_fetch_as_iterator(self, req, observations, extra_request_metadata, progress)
#    2060     raise kb
#    2061 except Exception as error:
# -> 2062     self._handle_error(error)
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py:2380, in SparkConnectClient._handle_error(self, error)
#    2378     self.thread_local.inside_error_handling = True
#    2379     if isinstance(error, grpc.RpcError):
# -> 2380         self._handle_rpc_error(error)
#    2381     raise error
#    2382 finally:
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py:2458, in SparkConnectClient._handle_rpc_error(self, rpc_error)
#    2454             logger.debug(f"Received ErrorInfo: {info}")
#    2456             self._handle_rpc_error_with_error_info(info, status.message, status_code)  # EDGE
# -> 2458             raise convert_exception(
#    2459                 info,
#    2460                 status.message,
#    2461                 self._fetch_enriched_error(info),
#    2462                 self._display_server_stack_trace(),
#    2463                 status_code,
#    2464             ) from None
#    2466     raise SparkConnectGrpcException(
#    2467         message=status.message,
#    2468         sql_state=ErrorCode.CLIENT_UNEXPECTED_MISSING_SQL_STATE,  # EDGE
#    2469         grpc_status_code=status_code,
#    2470     ) from None
#    2471 else:
#
# AnalysisException: [TABLE_OR_VIEW_NOT_FOUND] The table or view `bookings` cannot be found. Verify the spelling and correctness of the schema and catalog.
# Search path: [`system`.`session`, `system`.`builtin`, `system`.`ai`, `workspace`.`default`].
# If you did not qualify the name with a schema, verify the current_schema() output, or qualify the name with the correct schema and catalog.
# To tolerate the error on drop use DROP VIEW IF EXISTS or DROP TABLE IF EXISTS. SQLSTATE: 42P01; line 9 pos 9;
# 'Project ['passenger_name AS Original name#14862, 'TRIM('passenger_name) AS Trimmed name#14863, 'UPPER('TRIM('passenger_name)) AS Upper name#14864, 'LOWER('TRIM('passenger_name)) AS Lower name#14865, 'INITCAP('TRIM('passenger_name)) AS Title name#14866, 'LENGTH('TRIM('passenger_name)) AS Length of name#14867]
# +- 'UnresolvedRelation [bookings], [], false
#
#
# JVM stacktrace:
# org.apache.spark.sql.catalyst.ExtendedAnalysisException
# 	at org.apache.spark.sql.errors.QueryCompilationErrors$.tableOrViewNotFoundWithSearchPath(QueryCompilationErrors.scala:1464)
# 	at org.apache.spark.sql.catalyst.analysis.package$AnalysisErrorAt.tableNotFound(package.scala:97)
# 	at org.apache.spark.sql.catalyst.analysis.RelationResolution$.throwTableNotFound(RelationResolution.scala:1806)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.$anonfun$checkAnalysis0$2(CheckAnalysis.scala:467)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.$anonfun$checkAnalysis0$2$adapted(CheckAnalysis.scala:410)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.foreachUp(TreeNode.scala:392)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.$anonfun$foreachUp$1(TreeNode.scala:391)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.$anonfun$foreachUp$1$adapted(TreeNode.scala:391)
# 	at scala.collection.immutable.Vector.foreach(Vector.scala:2125)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.foreachUp(TreeNode.scala:391)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.checkAnalysis0(CheckAnalysis.scala:410)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.checkAnalysis0$(CheckAnalysis.scala:377)
# 	at org.apache.spark.sql.catalyst.analysis.Analyzer.checkAnalysis0(Analyzer.scala:636)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.$anonfun$checkAnalysis$1(CheckAnalysis.scala:362)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.spark.util.FrameProfiler$.$anonfun$record$1(FrameProfiler.scala:114)
# 	at com.databricks.spark.util.FrameProfilerExporter$.maybeExportFrameProfiler(FrameProfilerExporter.scala:201)
# 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:105)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.checkAnalysis(CheckAnalysis.scala:349)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.checkAnalysis$(CheckAnalysis.scala:345)
# 	at org.apache.spark.sql.catalyst.analysis.Analyzer.checkAnalysis(Analyzer.scala:636)
# 	at org.apache.spark.sql.catalyst.analysis.resolver.HybridAnalyzer.$anonfun$resolveInFixedPoint$1(HybridAnalyzer.scala:417)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at org.apache.spark.sql.catalyst.QueryPlanningTracker$.withTracker(QueryPlanningTracker.scala:275)
# 	at org.apache.spark.sql.catalyst.analysis.resolver.HybridAnalyzer.resolveInFixedPoint(HybridAnalyzer.scala:417)
# 	at org.apache.spark.sql.catalyst.analysis.resolver.HybridAnalyzer.$anonfun$apply$1(HybridAnalyzer.scala:98)
# 	at org.apache.spark.sql.catalyst.analysis.resolver.HybridAnalyzer.withTrackedAnalyzerBridgeState(HybridAnalyzer.scala:135)
# 	at org.apache.spark.sql.catalyst.analysis.resolver.HybridAnalyzer.apply(HybridAnalyzer.scala:91)
# 	at org.apache.spark.sql.catalyst.analysis.Analyzer.$anonfun$executeAndCheck$2(Analyzer.scala:703)
# 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper$.markInAnalyzer(AnalysisHelper.scala:425)
# 	at org.apache.spark.sql.catalyst.analysis.Analyzer.$anonfun$executeAndCheck$1(Analyzer.scala:703)
# 	at com.databricks.sql.unity.SAMSnapshotHelper$.visitPlansDuringAnalysis(SAMSnapshotHelper.scala:43)
# 	at org.apache.spark.sql.catalyst.analysis.Analyzer.executeAndCheck(Analyzer.scala:692)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$lazyAnalyzed$3(QueryExecution.scala:607)
# 	at com.databricks.spark.util.FrameProfiler$.$anonfun$record$1(FrameProfiler.scala:114)
# 	at com.databricks.spark.util.FrameProfilerExporter$.maybeExportFrameProfiler(FrameProfilerExporter.scala:201)
# 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:105)
# 	at org.apache.spark.sql.catalyst.QueryPlanningTracker.measurePhase(QueryPlanningTracker.scala:1021)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$8(QueryExecution.scala:1073)
# 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withExecutionPhase$1(SQLExecution.scala:337)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:349)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:345)
# 	at com.databricks.util.TracingSpanUtils$.$anonfun$withTracing$4(TracingSpanUtils.scala:247)
# 	at com.databricks.util.TracingSpanUtils$.withTracing(TracingSpanUtils.scala:100)
# 	at com.databricks.util.TracingSpanUtils$.withTracing(TracingSpanUtils.scala:245)
# 	at com.databricks.spark.util.DatabricksTracingHelper.withSpan(DatabricksSparkTracingHelper.scala:154)
# 	at com.databricks.spark.util.DBRTracing$.withSpan(DBRTracing.scala:87)
# 	at org.apache.spark.sql.execution.SQLExecution$.withExecutionPhase(SQLExecution.scala:318)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$7(QueryExecution.scala:1073)
# 	at org.apache.spark.sql.execution.QueryExecution$.withInternalError(QueryExecution.scala:1822)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$5(QueryExecution.scala:1066)
# 	at com.databricks.util.LexicalThreadLocal$Handle.runWith(LexicalThreadLocal.scala:63)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$4(QueryExecution.scala:1063)
# 	at com.databricks.util.LexicalThreadLocal$Handle.runWith(LexicalThreadLocal.scala:63)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$3(QueryExecution.scala:1063)
# 	at com.databricks.util.LexicalThreadLocal$Handle.runWith(LexicalThreadLocal.scala:63)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$2(QueryExecution.scala:1062)
# 	at com.databricks.util.LexicalThreadLocal$Handle.runWith(LexicalThreadLocal.scala:63)
# 	at org.apache.spark.sql.execution.QueryExecution.localBlock$1(QueryExecution.scala:1043)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$withQueryExecutionId$4(QueryExecution.scala:1053)
# 	at com.databricks.unity.UCSManager$.withTemporaryScope(UCSManager.scala:168)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$withQueryExecutionId$3(QueryExecution.scala:1052)
# 	at org.apache.spark.sql.execution.QueryExecution$.$anonfun$runWithWrappers$2(QueryExecution.scala:2075)
# 	at org.apache.spark.sql.execution.QueryExecution$.org$apache$spark$sql$execution$QueryExecution$$runWithWrappers(QueryExecution.scala:2074)
# 	at org.apache.spark.sql.execution.QueryExecution.withQueryExecutionId(QueryExecution.scala:1053)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$1(QueryExecution.scala:1061)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:866)
# 	at org.apache.spark.sql.execution.QueryExecution.executePhase(QueryExecution.scala:1060)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$lazyAnalyzed$2(QueryExecution.scala:598)
# 	at com.databricks.sql.util.MemoryTrackerHelper.withMemoryTracking(MemoryTrackerHelper.scala:111)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$lazyAnalyzed$1(QueryExecution.scala:597)
# 	at scala.util.Try$.apply(Try.scala:217)
# 	at org.apache.spark.util.Utils$.doTryWithCallerStacktrace(Utils.scala:1796)
# 	at org.apache.spark.util.Utils$.getTryWithCallerStacktrace(Utils.scala:1846)
# 	at org.apache.spark.util.LazyTry.get(LazyTry.scala:78)
# 	at org.apache.spark.sql.execution.QueryExecution.analyzed(QueryExecution.scala:661)
# 	at org.apache.spark.sql.execution.QueryExecution.assertAnalyzed(QueryExecution.scala:520)
# 	at org.apache.spark.sql.classic.Dataset$.$anonfun$ofRows$3(Dataset.scala:157)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:866)
# 	at org.apache.spark.sql.classic.SparkSession.$anonfun$withActiveAndFrameProfiler$1(SparkSession.scala:1332)
# 	at com.databricks.spark.util.FrameProfiler$.$anonfun$record$1(FrameProfiler.scala:114)
# 	at com.databricks.spark.util.FrameProfilerExporter$.maybeExportFrameProfiler(FrameProfilerExporter.scala:201)
# 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:105)
# 	at org.apache.spark.sql.classic.SparkSession.withActiveAndFrameProfiler(SparkSession.scala:1332)
# 	at org.apache.spark.sql.classic.Dataset$.ofRows(Dataset.scala:149)
# 	at org.apache.spark.sql.classic.SparkSession.$anonfun$sql$6(SparkSession.scala:1017)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:866)
# 	at org.apache.spark.sql.classic.SparkSession.sql(SparkSession.scala:982)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.executeSQL(SparkConnectPlanner.scala:4303)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.handleSqlCommand(SparkConnectPlanner.scala:4096)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.process(SparkConnectPlanner.scala:3790)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.handleCommand(ExecuteThreadRunner.scala:530)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.$anonfun$executeInternal$1(ExecuteThreadRunner.scala:420)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.$anonfun$executeInternal$1$adapted(ExecuteThreadRunner.scala:340)
# 	at org.apache.spark.sql.connect.service.SessionHolder.$anonfun$withSession$2(SessionHolder.scala:844)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:866)
# 	at org.apache.spark.sql.connect.service.SessionHolder.$anonfun$withSession$1(SessionHolder.scala:844)
# 	at org.apache.spark.JobArtifactSet$.withActiveJobArtifactState(JobArtifactSet.scala:97)
# 	at org.apache.spark.sql.artifact.ArtifactManager.$anonfun$withResources$1(ArtifactManager.scala:124)
# 	at org.apache.spark.sql.artifact.ArtifactManager.withClassLoaderIfNeeded(ArtifactManager.scala:118)
# 	at org.apache.spark.sql.artifact.ArtifactManager.withResources(ArtifactManager.scala:123)
# 	at org.apache.spark.sql.connect.service.SessionHolder.withSession(SessionHolder.scala:843)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.executeInternal(ExecuteThreadRunner.scala:340)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.$anonfun$execute$1(ExecuteThreadRunner.scala:200)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.spark.connect.service.UtilizationMetrics.recordActiveQueries(UtilizationMetrics.scala:92)
# 	at com.databricks.spark.connect.service.UtilizationMetrics.recordActiveQueries$(UtilizationMetrics.scala:89)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.recordActiveQueries(ExecuteThreadRunner.scala:61)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.org$apache$spark$sql$connect$execution$ExecuteThreadRunner$$execute(ExecuteThreadRunner.scala:192)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner$ExecutionThread.$anonfun$run$3(ExecuteThreadRunner.scala:601)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:349)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:345)
# 	at com.databricks.spark.util.DatabricksTracingHelper.$anonfun$withSpanFromParent$4(DatabricksSparkTracingHelper.scala:106)
# 	at com.databricks.util.TracingSpanUtils$.withTracing(TracingSpanUtils.scala:100)
# 	at com.databricks.spark.util.DatabricksTracingHelper.withSpanFromParent(DatabricksSparkTracingHelper.scala:104)
# 	at com.databricks.spark.util.DBRTracing$.withSpanFromParent(DBRTracing.scala:68)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner$ExecutionThread.$anonfun$run$2(ExecuteThreadRunner.scala:601)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.unity.UCSEphemeralState$Handle.runWith(UCSEphemeralState.scala:51)
# 	at com.databricks.unity.HandleImpl.runWith(UCSHandle.scala:128)
# 	at com.databricks.unity.HandleImpl.$anonfun$runWithAndClose$1(UCSHandle.scala:133)
# 	at scala.util.Using$.resource(Using.scala:296)
# 	at com.databricks.unity.HandleImpl.runWithAndClose(UCSHandle.scala:132)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner$ExecutionThread.run(ExecuteThreadRunner.scala:600)

# %% [markdown]
# ## Question 58 — Spark SQL
#
# Use SQL CASE to create the same fare_category used in the DataFrame assignment.
#
# **Functions/concepts:** `CASE WHEN`

# %%
spark.sql(
"""
SELECT
FORMAT_NUMBER(ticket_amount, 2) AS ticket_amount,
CASE
WHEN ticket_amount >= 10000 THEN 'PREMIUM'
WHEN ticket_amount >= 6000 THEN 'STANDARD'
ELSE 'BUDGET'
END AS fare_category
FROM bookings
""").show(truncate=False)

# %% [markdown]
# ## Question 59 — Spark SQL
#
# Use SQL COALESCE to replace null promo_discount with 0.
#
# **Functions/concepts:** `COALESCE`

# %%
# TODO Question 59
# Write your PySpark solution below.
spark.sql(
"""
SELECT COALESCE(promo_discount,0) from bookings
"""
).show(truncate = False)
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-5171890123933043>, line 3
#       1 # TODO Question 59
#       2 # Write your PySpark solution below.
# ----> 3 spark.sql(
#       4 """
#       5 SELECT COALESCE(promo_discount,0) from bookings
#       6 """
#       7 ).show(truncate = False)
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/session.py:901, in SparkSession.sql(self, sqlQuery, args, **kwargs)
#     898         _views.append(SubqueryAlias(df._plan, name))
#     900 cmd = SQL(sqlQuery, _args, _named_args, _views)
# --> 901 data, properties, ei = self.client.execute_command(cmd.command(self._client))
#     902 if "sql_command_result" in properties:
#     903     df = DataFrame(CachedRelation(properties["sql_command_result"]), self)
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py:1538, in SparkConnectClient.execute_command(self, command, observations, extra_request_metadata)
#    1536     req.user_context.user_id = self._user_id
#    1537 self._set_command_in_plan(req.plan, command)
# -> 1538 data, _, metrics, observed_metrics, properties = self._execute_and_fetch(
#    1539     req, observations or {}, extra_request_metadata
#    1540 )
#    1541 # Create a query execution object.
#    1542 ei = ExecutionInfo(metrics, observed_metrics)
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py:2086, in SparkConnectClient._execute_and_fetch(self, req, observations, extra_request_metadata, self_destruct)
#    2083 properties: Dict[str, Any] = {}
#    2085 with Progress(handlers=self._progress_handlers, operation_id=req.operation_id) as progress:
# -> 2086     for response in self._execute_and_fetch_as_iterator(
#    2087         req, observations, extra_request_metadata or [], progress=progress
#    2088     ):
#    2089         if isinstance(response, StructType):
#    2090             schema = response
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py:2062, in SparkConnectClient._execute_and_fetch_as_iterator(self, req, observations, extra_request_metadata, progress)
#    2060     raise kb
#    2061 except Exception as error:
# -> 2062     self._handle_error(error)
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py:2380, in SparkConnectClient._handle_error(self, error)
#    2378     self.thread_local.inside_error_handling = True
#    2379     if isinstance(error, grpc.RpcError):
# -> 2380         self._handle_rpc_error(error)
#    2381     raise error
#    2382 finally:
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py:2458, in SparkConnectClient._handle_rpc_error(self, rpc_error)
#    2454             logger.debug(f"Received ErrorInfo: {info}")
#    2456             self._handle_rpc_error_with_error_info(info, status.message, status_code)  # EDGE
# -> 2458             raise convert_exception(
#    2459                 info,
#    2460                 status.message,
#    2461                 self._fetch_enriched_error(info),
#    2462                 self._display_server_stack_trace(),
#    2463                 status_code,
#    2464             ) from None
#    2466     raise SparkConnectGrpcException(
#    2467         message=status.message,
#    2468         sql_state=ErrorCode.CLIENT_UNEXPECTED_MISSING_SQL_STATE,  # EDGE
#    2469         grpc_status_code=status_code,
#    2470     ) from None
#    2471 else:
#
# AnalysisException: [TABLE_OR_VIEW_NOT_FOUND] The table or view `bookings` cannot be found. Verify the spelling and correctness of the schema and catalog.
# Search path: [`system`.`session`, `system`.`builtin`, `system`.`ai`, `workspace`.`default`].
# If you did not qualify the name with a schema, verify the current_schema() output, or qualify the name with the correct schema and catalog.
# To tolerate the error on drop use DROP VIEW IF EXISTS or DROP TABLE IF EXISTS. SQLSTATE: 42P01; line 2 pos 39;
# 'Project [unresolvedalias('COALESCE('promo_discount, 0))]
# +- 'UnresolvedRelation [bookings], [], false
#
#
# JVM stacktrace:
# org.apache.spark.sql.catalyst.ExtendedAnalysisException
# 	at org.apache.spark.sql.errors.QueryCompilationErrors$.tableOrViewNotFoundWithSearchPath(QueryCompilationErrors.scala:1464)
# 	at org.apache.spark.sql.catalyst.analysis.package$AnalysisErrorAt.tableNotFound(package.scala:97)
# 	at org.apache.spark.sql.catalyst.analysis.RelationResolution$.throwTableNotFound(RelationResolution.scala:1806)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.$anonfun$checkAnalysis0$2(CheckAnalysis.scala:467)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.$anonfun$checkAnalysis0$2$adapted(CheckAnalysis.scala:410)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.foreachUp(TreeNode.scala:392)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.$anonfun$foreachUp$1(TreeNode.scala:391)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.$anonfun$foreachUp$1$adapted(TreeNode.scala:391)
# 	at scala.collection.immutable.Vector.foreach(Vector.scala:2125)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.foreachUp(TreeNode.scala:391)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.checkAnalysis0(CheckAnalysis.scala:410)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.checkAnalysis0$(CheckAnalysis.scala:377)
# 	at org.apache.spark.sql.catalyst.analysis.Analyzer.checkAnalysis0(Analyzer.scala:636)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.$anonfun$checkAnalysis$1(CheckAnalysis.scala:362)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.spark.util.FrameProfiler$.$anonfun$record$1(FrameProfiler.scala:114)
# 	at com.databricks.spark.util.FrameProfilerExporter$.maybeExportFrameProfiler(FrameProfilerExporter.scala:201)
# 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:105)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.checkAnalysis(CheckAnalysis.scala:349)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.checkAnalysis$(CheckAnalysis.scala:345)
# 	at org.apache.spark.sql.catalyst.analysis.Analyzer.checkAnalysis(Analyzer.scala:636)
# 	at org.apache.spark.sql.catalyst.analysis.resolver.HybridAnalyzer.$anonfun$resolveInFixedPoint$1(HybridAnalyzer.scala:417)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at org.apache.spark.sql.catalyst.QueryPlanningTracker$.withTracker(QueryPlanningTracker.scala:275)
# 	at org.apache.spark.sql.catalyst.analysis.resolver.HybridAnalyzer.resolveInFixedPoint(HybridAnalyzer.scala:417)
# 	at org.apache.spark.sql.catalyst.analysis.resolver.HybridAnalyzer.$anonfun$apply$1(HybridAnalyzer.scala:98)
# 	at org.apache.spark.sql.catalyst.analysis.resolver.HybridAnalyzer.withTrackedAnalyzerBridgeState(HybridAnalyzer.scala:135)
# 	at org.apache.spark.sql.catalyst.analysis.resolver.HybridAnalyzer.apply(HybridAnalyzer.scala:91)
# 	at org.apache.spark.sql.catalyst.analysis.Analyzer.$anonfun$executeAndCheck$2(Analyzer.scala:703)
# 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper$.markInAnalyzer(AnalysisHelper.scala:425)
# 	at org.apache.spark.sql.catalyst.analysis.Analyzer.$anonfun$executeAndCheck$1(Analyzer.scala:703)
# 	at com.databricks.sql.unity.SAMSnapshotHelper$.visitPlansDuringAnalysis(SAMSnapshotHelper.scala:43)
# 	at org.apache.spark.sql.catalyst.analysis.Analyzer.executeAndCheck(Analyzer.scala:692)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$lazyAnalyzed$3(QueryExecution.scala:607)
# 	at com.databricks.spark.util.FrameProfiler$.$anonfun$record$1(FrameProfiler.scala:114)
# 	at com.databricks.spark.util.FrameProfilerExporter$.maybeExportFrameProfiler(FrameProfilerExporter.scala:201)
# 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:105)
# 	at org.apache.spark.sql.catalyst.QueryPlanningTracker.measurePhase(QueryPlanningTracker.scala:1021)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$8(QueryExecution.scala:1073)
# 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withExecutionPhase$1(SQLExecution.scala:337)
# 	at com.databricks.util.TracingSpanUtils$.withTracing(TracingSpanUtils.scala:251)
# 	at com.databricks.spark.util.DatabricksTracingHelper.withSpan(DatabricksSparkTracingHelper.scala:154)
# 	at com.databricks.spark.util.DBRTracing$.withSpan(DBRTracing.scala:87)
# 	at org.apache.spark.sql.execution.SQLExecution$.withExecutionPhase(SQLExecution.scala:318)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$7(QueryExecution.scala:1073)
# 	at org.apache.spark.sql.execution.QueryExecution$.withInternalError(QueryExecution.scala:1822)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$5(QueryExecution.scala:1066)
# 	at com.databricks.util.LexicalThreadLocal$Handle.runWith(LexicalThreadLocal.scala:63)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$4(QueryExecution.scala:1063)
# 	at com.databricks.util.LexicalThreadLocal$Handle.runWith(LexicalThreadLocal.scala:63)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$3(QueryExecution.scala:1063)
# 	at com.databricks.util.LexicalThreadLocal$Handle.runWith(LexicalThreadLocal.scala:63)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$2(QueryExecution.scala:1062)
# 	at com.databricks.util.LexicalThreadLocal$Handle.runWith(LexicalThreadLocal.scala:63)
# 	at org.apache.spark.sql.execution.QueryExecution.localBlock$1(QueryExecution.scala:1043)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$withQueryExecutionId$4(QueryExecution.scala:1053)
# 	at com.databricks.unity.UCSManager$.withTemporaryScope(UCSManager.scala:168)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$withQueryExecutionId$3(QueryExecution.scala:1052)
# 	at org.apache.spark.sql.execution.QueryExecution$.$anonfun$runWithWrappers$2(QueryExecution.scala:2075)
# 	at org.apache.spark.sql.execution.QueryExecution$.org$apache$spark$sql$execution$QueryExecution$$runWithWrappers(QueryExecution.scala:2074)
# 	at org.apache.spark.sql.execution.QueryExecution.withQueryExecutionId(QueryExecution.scala:1053)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$1(QueryExecution.scala:1061)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:866)
# 	at org.apache.spark.sql.execution.QueryExecution.executePhase(QueryExecution.scala:1060)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$lazyAnalyzed$2(QueryExecution.scala:598)
# 	at com.databricks.sql.util.MemoryTrackerHelper.withMemoryTracking(MemoryTrackerHelper.scala:111)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$lazyAnalyzed$1(QueryExecution.scala:597)
# 	at scala.util.Try$.apply(Try.scala:217)
# 	at org.apache.spark.util.Utils$.doTryWithCallerStacktrace(Utils.scala:1796)
# 	at org.apache.spark.util.Utils$.getTryWithCallerStacktrace(Utils.scala:1846)
# 	at org.apache.spark.util.LazyTry.get(LazyTry.scala:78)
# 	at org.apache.spark.sql.execution.QueryExecution.analyzed(QueryExecution.scala:661)
# 	at org.apache.spark.sql.execution.QueryExecution.assertAnalyzed(QueryExecution.scala:520)
# 	at org.apache.spark.sql.classic.Dataset$.$anonfun$ofRows$3(Dataset.scala:157)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:866)
# 	at org.apache.spark.sql.classic.SparkSession.$anonfun$withActiveAndFrameProfiler$1(SparkSession.scala:1332)
# 	at com.databricks.spark.util.FrameProfiler$.$anonfun$record$1(FrameProfiler.scala:114)
# 	at com.databricks.spark.util.FrameProfilerExporter$.maybeExportFrameProfiler(FrameProfilerExporter.scala:201)
# 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:105)
# 	at org.apache.spark.sql.classic.SparkSession.withActiveAndFrameProfiler(SparkSession.scala:1332)
# 	at org.apache.spark.sql.classic.Dataset$.ofRows(Dataset.scala:149)
# 	at org.apache.spark.sql.classic.SparkSession.$anonfun$sql$6(SparkSession.scala:1017)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:866)
# 	at org.apache.spark.sql.classic.SparkSession.sql(SparkSession.scala:982)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.executeSQL(SparkConnectPlanner.scala:4303)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.handleSqlCommand(SparkConnectPlanner.scala:4096)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.process(SparkConnectPlanner.scala:3790)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.handleCommand(ExecuteThreadRunner.scala:530)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.$anonfun$executeInternal$1(ExecuteThreadRunner.scala:420)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.$anonfun$executeInternal$1$adapted(ExecuteThreadRunner.scala:340)
# 	at org.apache.spark.sql.connect.service.SessionHolder.$anonfun$withSession$2(SessionHolder.scala:844)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:866)
# 	at org.apache.spark.sql.connect.service.SessionHolder.$anonfun$withSession$1(SessionHolder.scala:844)
# 	at org.apache.spark.JobArtifactSet$.withActiveJobArtifactState(JobArtifactSet.scala:97)
# 	at org.apache.spark.sql.artifact.ArtifactManager.$anonfun$withResources$1(ArtifactManager.scala:124)
# 	at org.apache.spark.sql.artifact.ArtifactManager.withClassLoaderIfNeeded(ArtifactManager.scala:118)
# 	at org.apache.spark.sql.artifact.ArtifactManager.withResources(ArtifactManager.scala:123)
# 	at org.apache.spark.sql.connect.service.SessionHolder.withSession(SessionHolder.scala:843)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.executeInternal(ExecuteThreadRunner.scala:340)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.$anonfun$execute$1(ExecuteThreadRunner.scala:200)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.spark.connect.service.UtilizationMetrics.recordActiveQueries(UtilizationMetrics.scala:92)
# 	at com.databricks.spark.connect.service.UtilizationMetrics.recordActiveQueries$(UtilizationMetrics.scala:89)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.recordActiveQueries(ExecuteThreadRunner.scala:61)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.org$apache$spark$sql$connect$execution$ExecuteThreadRunner$$execute(ExecuteThreadRunner.scala:192)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner$ExecutionThread.$anonfun$run$3(ExecuteThreadRunner.scala:601)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.spark.util.DBRTracing$.withSpanFromParent(DBRTracing.scala:70)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner$ExecutionThread.$anonfun$run$2(ExecuteThreadRunner.scala:601)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.unity.UCSEphemeralState$Handle.runWith(UCSEphemeralState.scala:51)
# 	at com.databricks.unity.HandleImpl.runWith(UCSHandle.scala:128)
# 	at com.databricks.unity.HandleImpl.$anonfun$runWithAndClose$1(UCSHandle.scala:133)
# 	at scala.util.Using$.resource(Using.scala:296)
# 	at com.databricks.unity.HandleImpl.runWithAndClose(UCSHandle.scala:132)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner$ExecutionThread.run(ExecuteThreadRunner.scala:600)

# %% [markdown]
# ## Question 60 — Spark SQL
#
# Create an airline-level aggregation using SQL.
#
# **Functions/concepts:** `COUNT, AVG, SUM, MIN, MAX, COUNT DISTINCT`

# %%
bookings_df.createOrReplaceTempView("bookings")

Airline_aggregation_df = spark.sql("""
    SELECT
        airline_code,
        COUNT(*) AS `Amount of bookings`,
        ROUND(AVG(ticket_amount), 2) AS `Average ticket amount`,
        ROUND(SUM(ticket_amount), 2) AS `Total ticket amount`,
        ROUND(MIN(ticket_amount), 2) AS `Minimum ticket amount`,
        ROUND(MAX(ticket_amount), 2) AS `Maximum ticket amount`
    FROM bookings
    GROUP BY airline_code
    ORDER BY airline_code
""")

Airline_aggregation_df.show(truncate=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <command-5171890123933045>, line 1
# ----> 1 bookings_df.createOrReplaceTempView("bookings")
#       3 Airline_aggregation_df = spark.sql("""
#       4     SELECT
#       5         airline_code,
#    (...)
#      13     ORDER BY airline_code
#      14 """)
#      16 Airline_aggregation_df.show(truncate=False)
#
# NameError: name 'bookings_df' is not defined

# %% [markdown]
# ## Question 61 — Spark SQL
#
# Join the booking view with airline and route views in SQL.
#
# **Functions/concepts:** `SQL JOIN`

# %%
bookings_df.createOrReplaceTempView("bookings")
airline_df.createOrReplaceTempView("airline")
route_df.createOrReplaceTempView("route")

joinDF = spark.sql(
"""
select 
bookings.*,
airline.airline_name
from bookings
join airline
on bookings.airline_code = airline.airline_code
join route
on bookings.route_code = route.route_code

"""
).show(truncate = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <command-5171890123933047>, line 1
# ----> 1 bookings_df.createOrReplaceTempView("bookings")
#       2 airline_df.createOrReplaceTempView("airline")
#       3 route_df.createOrReplaceTempView("route")
#
# NameError: name 'bookings_df' is not defined

# %% [markdown]
# ## Question 62 — Databricks
#
# Display sql_airline_aggregation_df and create a bar-chart visualization using airline_code on the X-axis and total_fare on the Y-axis.
#
# **Functions/concepts:** `display visualization`

# %%
sql_airline_aggregation_df = Airline_aggregation_df.withColumnRenamed(
    "Total ticket amount", "total_fare"
)
display(sql_airline_aggregation_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <command-5171890123933049>, line 1
# ----> 1 sql_airline_aggregation_df = Airline_aggregation_df.withColumnRenamed(
#       2     "Total ticket amount", "total_fare"
#       3 )
#       4 display(sql_airline_aggregation_df)
#
# NameError: name 'Airline_aggregation_df' is not defined

# %% [markdown]
# ## Question 63 — Databricks
#
# Optionally save sql_airline_aggregation_df as a managed table and query it again.
#
# **Functions/concepts:** `saveAsTable, spark.table`

# %%
# Declare new dataframe
sql_airline_aggregation_df = Airline_aggregation_df

# Write table to catelog
sql_airline_aggregation_df.write.mode("overwrite").saveAsTable("sql_airline_aggregation")

# Query table
spark.table("sql_airline_aggregation").show(truncate=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <command-5171890123933051>, line 2
#       1 # Declare new dataframe
# ----> 2 sql_airline_aggregation_df = Airline_aggregation_df
#       4 # Write table to catelog
#       5 sql_airline_aggregation_df.write.mode("overwrite").saveAsTable("sql_airline_aggregation")
#
# NameError: name 'Airline_aggregation_df' is not defined

# %% [markdown]
# ## Question 64 — Execution plan
#
# Use explain(mode='formatted') on sql_airline_aggregation_df and identify Scan, Project, Filter, Exchange, HashAggregate, and Sort where present.
#
# **Functions/concepts:** `explain`

# %%
# TODO Question 64
# Write your PySpark solution below.

# Add explain to idneitfy lineage
sql_airline_aggregation_df.explain(mode="formatted")

# %% [markdown]
# ## Question 65 — Spark execution
#
# Separate examples of transformations and actions from this assignment. Run count() and collect() only on a small aggregate.
#
# **Functions/concepts:** `transformations, actions, collect`

# %%
# Examples from this assignment:
filetered_df = bookings_df.filter(F.col("ticket_amount") > 8000)  
selected_df = bookings_df.select("booking_id", "ticket_amount") 
renamed_df = bookings_df.withColumnRenamed("booking_status", "reservation_status")  
grouped_df = bookings_df.groupBy("airline_code").agg(F.sum("ticket_amount")) 
sorted_df = bookings_df.orderBy(F.col("ticket_amount").desc()) 

# Display # of rows
print("Row count:", sql_airline_aggregation_df.count())

# Display content
print("Collected rows:", sql_airline_aggregation_df.collect())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <command-5171890123933055>, line 10
#       7 sorted_df = bookings_df.orderBy(F.col("ticket_amount").desc())
#       9 # Display # of rows
# ---> 10 print("Row count:", sql_airline_aggregation_df.count())
#      12 # Display content
#      13 print("Collected rows:", sql_airline_aggregation_df.collect())
#
# NameError: name 'sql_airline_aggregation_df' is not defined

# %% [markdown]
# ## Question 66 — Partitions
#
# Reduce sql_airline_aggregation_df to one partition using DataFrame.coalesce(1). Explain why this should not be used blindly for large production data.
#
# **Functions/concepts:** `DataFrame.coalesce`

# %%
# TODO Question 66
# Write your PySpark solution below.

partition_df = sql_airline_aggregation_df.coalesce(1)

print("Partitions before:", sql_airline_aggregation_df.rdd.getNumPartitions())
print("Partitions after:", partition_df.rdd.getNumPartitions())

partition_df.show(truncate=False)
